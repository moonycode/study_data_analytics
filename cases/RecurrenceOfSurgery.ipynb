# %%
import pandas as pd

# %%
import pymongo as mg

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
database = client['db_medicals']
database
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'db_medicals')

# %%
collection = database['RecurrenceOfSurgery']
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'db_medicals'), 'RecurrenceOfSurgery')

# %%
cursor = collection.find({})
list_cursor = list(cursor)

# %%
pd.set_option('display.max_columns', None)
df_ROS_mongo=pd.DataFrame(list_cursor)
df_ROS_mongo
# Out:
#                            _id  Unnamed: 0    환자ID  Large Lymphocyte  \
# 0     64d359fb88bc32c8799414e6           0     1PT              22.8
# 1     64d359fb88bc32c8799414e7           1     2PT              44.9
# 2     64d359fb88bc32c8799414e8           2     3PT              53.0
# 3     64d359fb88bc32c8799414e9           3     4PT              54.7
# 4     64d359fb88bc32c8799414ea           4     5PT              53.8
# ...                        ...         ...     ...               ...
# 1889  64d359fb88bc32c879941c47        1889  1890PT              44.0
# 1890  64d359fb88bc32c879941c48        1890  1891PT              30.8
# 1891  64d359fb88bc32c879941c49        1891  1892PT              36.7
# 1892  64d359fb88bc32c879941c4a        1892  1893PT              32.5
# 1893  64d359fb88bc32c879941c4b        1893  1894PT              49.5
#
#       Location of herniation   ODI  가족력  간질성폐질환  고혈압여부  과거수술횟수  당뇨여부  \
# 0                          3  51.0  0.0       0      0       0     0
# 1                          4  26.0  0.0       0      0       0     0
# 2                          3   NaN  0.0       0      0       1     0
# 3                          4  18.0  0.0       0      1       0     0
# 4                          4   NaN  0.0       0      1       0     0
# ...                      ...   ...  ...     ...    ...     ...   ...
# 1889                       1   NaN  0.0       0      0       0     0
# 1890                       2   NaN  0.0       0      0       0     0
# 1891                       3   NaN  0.0       0      0       0     0
# 1892                       2   NaN  0.0       0      0       0     0
# 1893                       2   NaN  0.0       0      0       0     0
#
#       말초동맥질환여부  빈혈여부  성별  스테로이드치료  신부전여부   신장  심혈관질환  암발병여부  연령  우울증여부  입원기간  \
# 0            0     0   2        1      0  163      0      0  66      0     2
# 1            0     0   1        1      0  171      0      0  47      0     1
# 2            0     0   1        1      0  178      0      0  39      0     1
# 3            0     0   1        0      0  174      0      0  40      0     1
# 4            0     0   1        1      0  183      0      0  42      0     2
# ...        ...   ...  ..      ...    ...  ...    ...    ...  ..    ...   ...
# 1889         0     0   2        1      0  157      0      0  59      0     2
# 1890         0     0   2        1      0  157      0      0  42      0     4
# 1891         1     0   1        1      0  167      0      0  61      0     3
# 1892         0     0   1        1      0  177      0      0  29      0     4
# 1893         0     0   2        1      0  168      0      0  30      0     2
#
#           입원일자  종양진행여부     직업    체중      퇴원일자  헤모글로빈수치  혈전합병증여부  환자통증정도  흡연여부  \
# 0     20190713       0    자영업  60.3  20190716    13.66        0      10     0
# 1     20190715       0   운동선수  71.7  20190716    13.73        0      10     0
# 2     20190729       0  특수전문직  77.1  20190801    15.34        0       7     0
# 3     20190731       0     주부  74.2  20190803    15.38        0       7     0
# 4     20190903       0  특수전문직  80.7  20190907    13.08        0       7     0
# ...        ...     ...    ...   ...       ...      ...      ...     ...   ...
# 1889  20170407       1     무직  64.0  20170408    13.60        0       7     0
# 1890  20170426       0    사무직  59.0  20170429    13.00        0       7     0
# 1891  20170410       0     무직  70.0  20170412    14.40        0       7     0
# 1892  20170408       0    사무직  77.0  20170411    15.00        0       7     0
# 1893  20170412       0    사무직  49.0  20170413    13.20        0       8     0
#
#       통증기간(월)  수술기법  수술시간  수술실패여부      수술일자  재발여부    혈액형  전방디스크높이(mm)  \
# 0         1.0  TELD  68.0       0  20190715     0   RH+A         16.1
# 1         1.0  TELD  31.0       0  20190716     0   RH+A         13.7
# 2         1.0  TELD  78.0       0  20190731     0   RH+B         13.6
# 3         2.0  TELD  73.0       0  20190802     0   RH+O         10.6
# 4         1.0  TELD  29.0       0  20190906     0   RH+A         17.1
# ...       ...   ...   ...     ...       ...   ...    ...          ...
# 1889     12.0   NaN  80.0       0  20170407     0   RH+A         17.0
# 1890      6.0   NaN  20.0       0  20170427     0   RH+B          9.4
# 1891      1.0  IELD  50.0       0  20170411     0   RH+O         13.5
# 1892     24.0   NaN  25.0       0  20170410     0   RH+A         14.0
# 1893      6.0   NaN  45.0       0  20170412     0  RH+AB         16.1
#
#       후방디스크높이(mm)  지방축적도  Instability  MF + ES  Modic change    PI    PT  \
# 0            12.3  282.3            0   1824.6             3  51.6  36.6
# 1             6.4  177.3            0   1737.5             0  40.8   7.2
# 2             7.4  256.8            0   1188.5             0  67.5  27.3
# 3             7.3  250.1            0   2534.5             0  49.2  18.7
# 4             8.1  232.2            0   1840.6             0  58.8  14.7
# ...           ...    ...          ...      ...           ...   ...   ...
# 1889         10.7  237.5            0   2795.7             2  59.5  23.0
# 1890          8.2  288.0            0   1473.0             0  47.7  20.2
# 1891          5.5  148.5            0   3864.1             0  44.6  15.0
# 1892         10.0   89.0            0   2481.8             2  32.2  11.1
# 1893          9.5  251.4            0   1796.1             0  38.9   6.8
#
#       Seg Angle(raw)  Vaccum disc   골밀도   디스크단면적  디스크위치  척추이동척도  척추전방위증
# 0               14.4            0 -1.01  2048.50      4    Down       0
# 1               17.8            0 -1.14  1753.10      4      Up       0
# 2               10.2            0 -1.77  1749.00      4    Down       0
# 3               19.9            0 -1.58  1796.20      4    Down       0
# 4                5.2            0 -0.79  2021.48      4      Up       0
# ...              ...          ...   ...      ...    ...     ...     ...
# 1889            21.8            0   NaN  2652.20      5  Middle       0
# 1890             5.0            0   NaN  1795.80      4    Down       0
# 1891            17.4            1   NaN  2624.40      4    Down       0
# 1892            17.7            0   NaN  1972.50      5    Down       0
# 1893            27.8            0   NaN  1574.40      5  Middle       0
#
# [1894 rows x 53 columns]
