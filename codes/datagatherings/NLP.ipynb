# %%
! pip install tensorflow
# Out:
# ...
#                                               0.0/284.2 MB ? eta -:--:--
#                                               0.2/284.2 MB 4.6 MB/s eta 0:01:03
#                                               0.6/284.2 MB 7.5 MB/s eta 0:00:38
#                                              1.3/284.2 MB 10.1 MB/s eta 0:00:29
#                                              1.8/284.2 MB 10.4 MB/s eta 0:00:28
#                                              2.3/284.2 MB 10.5 MB/s eta 0:00:27
#                                              2.8/284.2 MB 10.6 MB/s eta 0:00:27
#                                              3.1/284.2 MB 10.6 MB/s eta 0:00:27
#                                              3.1/284.2 MB 10.6 MB/s eta 0:00:27
#                                              3.1/284.2 MB 10.6 MB/s eta 0:00:27
#                                              3.1/284.2 MB 10.6 MB/s eta 0:00:27
#                                              3.1/284.2 MB 10.6 MB/s eta 0:00:27
# ...

# %%
! pip install keras

# %%
! pip install gensim

# %%
! pip install scikit-learn

# %%
! pip install nltk

# %%
! nltk.download()
