# %%
! pip install tensorflow
! pip install keras
! pip install gensim
! pip install scikit-learn
! pip install nltk
# Out:
# Requirement already satisfied: tensorflow in c:\users\moony\anaconda3\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\moony\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\moony\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\moony\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\moony\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\moony\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\moony\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\moony\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\moony\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\moony\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\moony\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\moony\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\moony\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\moony\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\moony\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\moony\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\moony\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\moony\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)
# Requirement already satisfied: keras in c:\users\moony\anaconda3\lib\site-packages (2.14.0)
# Requirement already satisfied: gensim in c:\users\moony\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\moony\anaconda3\lib\site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\moony\anaconda3\lib\site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\moony\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in c:\users\moony\anaconda3\lib\site-packages (from gensim) (2.0.5)
# Requirement already satisfied: pandas in c:\users\moony\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (1.5.3)
# Requirement already satisfied: pyfume in c:\users\moony\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\moony\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\moony\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2022.7)
# Requirement already satisfied: simpful in c:\users\moony\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.11.0)
# Requirement already satisfied: fst-pso in c:\users\moony\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\moony\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Requirement already satisfied: miniful in c:\users\moony\anaconda3\lib\site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: scikit-learn in c:\users\moony\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\moony\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\moony\anaconda3\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\moony\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\moony\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: nltk in c:\users\moony\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\moony\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\moony\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\moony\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\moony\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\moony\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
! pip install typing-extensions
# Out:
# Requirement already satisfied: typing-extensions in c:\users\moony\anaconda3\lib\site-packages (4.7.1)

# %%
! pip install typing_extensions
# Out:
# Requirement already satisfied: typing_extensions in c:\users\moony\anaconda3\lib\site-packages (4.7.1)

# %%
! pip install -U pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
#      ---------------------------------------- 0.0/262.6 kB ? eta -:--:--
#      -------------------------------------  256.0/262.6 kB 7.7 MB/s eta 0:00:01
#      -------------------------------------- 262.6/262.6 kB 5.4 MB/s eta 0:00:00
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
#      ---------------------------------------- 0.0/309.8 kB ? eta -:--:--
#      -------------------------------------- 309.8/309.8 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in c:\users\moony\anaconda3\lib\site-packages (from pandas-profiling) (1.10.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\moony\anaconda3\lib\site-packages (from pandas-profiling) (1.5.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\moony\anaconda3\lib\site-packages (from pandas-profiling) (3.7.1)
# Collecting pydantic>=1.8.1 (from pandas-profiling)
#   Obtaining dependency information for pydantic>=1.8.1 from https://files.pythonhosted.org/packages/73/66/0a72c9fcde42e5650c8d8d5c5c1873b9a3893018020c77ca8eb62708b923/pydantic-2.4.2-py3-none-any.whl.metadata
#   Downloading pydantic-2.4.2-py3-none-any.whl.metadata (158 kB)
#      ---------------------------------------- 0.0/158.6 kB ? eta -:--:--
#      -------------------------------------- 158.6/158.6 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\moony\anaconda3\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\moony\anaconda3\lib\site-packages (from pandas-profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\moony\anaconda3\lib\site-packages (from pandas-profiling) (2.1.1)
# Collecting visions[type_image_path]==0.7.4 (from pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#      ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#      -------------------------------------- 102.4/102.4 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.0 in c:\users\moony\anaconda3\lib\site-packages (from pandas-profiling) (1.24.3)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Downloading phik-0.12.3-cp311-cp311-win_amd64.whl (663 kB)
#      ---------------------------------------- 0.0/663.4 kB ? eta -:--:--
#      ------------------------------------- 663.4/663.4 kB 20.4 MB/s eta 0:00:00
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#      --------- ------------------------------ 1.1/4.7 MB 33.9 MB/s eta 0:00:01
#      ------------------------ --------------- 2.9/4.7 MB 37.1 MB/s eta 0:00:01
#      ---------------------------------------  4.7/4.7 MB 42.9 MB/s eta 0:00:01
#      ---------------------------------------- 4.7/4.7 MB 30.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.24.0 in c:\users\moony\anaconda3\lib\site-packages (from pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\moony\anaconda3\lib\site-packages (from pandas-profiling) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\moony\anaconda3\lib\site-packages (from pandas-profiling) (0.12.2)
# Collecting multimethod>=1.4 (from pandas-profiling)
#   Obtaining dependency information for multimethod>=1.4 from https://files.pythonhosted.org/packages/7f/bd/750245e47e7f307d9f94d4fa84727f4ed9956005dfa671d58be1d531a0f6/multimethod-1.10-py3-none-any.whl.metadata
#   Downloading multimethod-1.10-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\moony\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\moony\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (3.1)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ---------------------------------------- 0.0/296.5 kB ? eta -:--:--
#      ------------------------------------- 296.5/296.5 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in c:\users\moony\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\moony\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\moony\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\moony\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\moony\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\moony\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\moony\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\moony\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\moony\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2022.7)
# Collecting annotated-types>=0.4.0 (from pydantic>=1.8.1->pandas-profiling)
#   Obtaining dependency information for annotated-types>=0.4.0 from https://files.pythonhosted.org/packages/28/78/d31230046e58c207284c6b2c4e8d96e6d3cb4e52354721b944d3e1ee4aa5/annotated_types-0.6.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.10.1 (from pydantic>=1.8.1->pandas-profiling)
#   Obtaining dependency information for pydantic-core==2.10.1 from https://files.pythonhosted.org/packages/7c/49/bd863a3d7c5412d739f3a28da0f437f25ccfa92413675c93412e64b812ed/pydantic_core-2.10.1-cp311-none-win_amd64.whl.metadata
#   Downloading pydantic_core-2.10.1-cp311-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\moony\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\moony\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\moony\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\moony\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\moony\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\moony\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\moony\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\moony\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.4.1)
# Downloading multimethod-1.10-py3-none-any.whl (9.9 kB)
# Downloading pydantic-2.4.2-py3-none-any.whl (395 kB)
#    ---------------------------------------- 0.0/395.8 kB ? eta -:--:--
#    --------------------------------------- 395.8/395.8 kB 24.1 MB/s eta 0:00:00
# Downloading pydantic_core-2.10.1-cp311-none-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 61.7 MB/s eta 0:00:00
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27092 sha256=0662e4d9ebde150cfa7ba8a8aa8742b61fcfa92c11bdb53ae2613ce7d3f6d436
#   Stored in directory: c:\users\moony\appdata\local\pip\cache\wheels\8d\55\1a\19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: htmlmin, tangled-up-in-unicode, pydantic-core, multimethod, joblib, annotated-types, pydantic, imagehash, visions, phik, missingno, pandas-profiling
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
# Successfully installed annotated-types-0.6.0 htmlmin-0.1.12 imagehash-4.3.1 joblib-1.1.1 missingno-0.5.2 multimethod-1.10 pandas-profiling-3.2.0 phik-0.12.3 pydantic-2.4.2 pydantic-core-2.10.1 tangled-up-in-unicode-0.2.0 visions-0.7.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 2.1.1 requires sentencepiece, which is not installed.

# %%
import tensorflow as tf
import keras
import gensim
import sklearn
import nltk
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumBarunGothic')

# %%
df_google = pd.read_csv('./google_drop_duplicates.csv', encoding='utf-8')

# %%
df_google.groupby('title').head(1)
# Out:
#        Unnamed: 0                           title downloads  \
# 0               0   케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기      50만+
# 1555         1555  케어네이션 - 일감 찾기, 간병인, 동행인, 요양보호사      10만+
# 2427         2427   숨고 - 이사, 인테리어, 레슨까지 전국민 생활솔루션     100만+
# 12708       12774               위피 - 동네 친구가 필요할 때     100만+
# 31863       32107               애니맨 - 실시간 도움 요청 앱      50만+
#
#                        rating  release_date  \
# 0      별표 5개 만점에 4.6개를 받았습니다.  2020. 3. 15.
# 1555   별표 5개 만점에 4.4개를 받았습니다.  2020. 3. 15.
# 2427   별표 5개 만점에 4.0개를 받았습니다.   2017. 3. 2.
# 12708  별표 5개 만점에 3.3개를 받았습니다.   2017. 9. 3.
# 31863  별표 5개 만점에 4.4개를 받았습니다.   2016. 6. 7.
#
#                                                     info        reviewer  \
# 0      🤎🤎간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗🤎🤎\n\n👉3...  n Butter Bread
# 1555   💙💙간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗💙💙\n\n👉 ...             김명희
# 2427   어떡하지? 숨고하지!\n전국민 생활솔루션 숨고가 당신의 어떡하지를 해결합니다.\n이...   Yeo Wool Kang
# 12708  편하게 만날 수 있는 동네 친구 어플, 위피\n▶ 데이트를 위해 만남이 필요할 때\...             윤영옥
# 31863  다른 사람의 도움이 필요하세요?\n이제 스트레스 받지 마세요. 애니맨이 해결해드릴게...             정다희
#
#                       stars   review_date  \
# 0      별표 5개 만점에 1개를 받았습니다.   2023년 8월 5일
# 1555   별표 5개 만점에 1개를 받았습니다.  2023년 9월 17일
# 2427   별표 5개 만점에 4개를 받았습니다.  2022년 12월 5일
# 12708  별표 5개 만점에 5개를 받았습니다.  2023년 10월 7일
# 31863  별표 5개 만점에 5개를 받았습니다.   2023년 8월 7일
#
#                                                  content
# 0      네트워크오류라고 나와서 와이파이 끄고 하면 로그인 안되고 일시적인 오류라고 계속 뜹...
# 1555   권한설정을 허용으로 해도 앱이 안열리고 그대로 권한설정하라고만 되어있어요 앱을 삭제...
# 2427   숨고를 이용하고 있는 과와 선생님입니다. 과외생들을 찾아서 좋은데, 개선할 점이 있...
# 12708  위피 채팅 진짜 물건이네요 ㅋㅋㅋ 한 몇달동안 여러 채팅앱 써본 결과 ? 가장 만족...
# 31863  모두에 입장에서 이용해봐도 편리한 어플이라 추천합니다 모든연령대 에서 쉽게 이용할수...

# %%
df_google.loc[df_google['title'] == '애니맨 - 실시간 도움 요청 앱', 'release_date'] = '2016. 6. 7.'

# %%
df_care_only = df_google[(df_google['title'] == '케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기') |  (df_google['title'] == '케어네이션 - 일감 찾기, 간병인, 동행인, 요양보호사')]
df_care_only.groupby('title').head(1)
# Out:
#       Unnamed: 0                           title downloads  \
# 0              0   케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기      50만+
# 1555        1555  케어네이션 - 일감 찾기, 간병인, 동행인, 요양보호사      10만+
#
#                       rating  release_date  \
# 0     별표 5개 만점에 4.6개를 받았습니다.  2020. 3. 15.
# 1555  별표 5개 만점에 4.4개를 받았습니다.  2020. 3. 15.
#
#                                                    info        reviewer  \
# 0     🤎🤎간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗🤎🤎\n\n👉3...  n Butter Bread
# 1555  💙💙간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗💙💙\n\n👉 ...             김명희
#
#                      stars   review_date  \
# 0     별표 5개 만점에 1개를 받았습니다.   2023년 8월 5일
# 1555  별표 5개 만점에 1개를 받았습니다.  2023년 9월 17일
#
#                                                 content
# 0     네트워크오류라고 나와서 와이파이 끄고 하면 로그인 안되고 일시적인 오류라고 계속 뜹...
# 1555  권한설정을 허용으로 해도 앱이 안열리고 그대로 권한설정하라고만 되어있어요 앱을 삭제...

# %%
df_care_only['rate_int'] = df_care_only['stars'].str.extract(r'별표 5개 만점에 (\d+)개를 받았습니다.').astype(int)
df_care_only
# Out:
# C:\Users\moony\AppData\Local\Temp\ipykernel_2928\3947758824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_care_only['rate_int'] = df_care_only['stars'].str.extract(r'별표 5개 만점에 (\d+)개를 받았습니다.').astype(int)
#       Unnamed: 0                           title downloads  \
# 0              0   케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기      50만+
# 1              1   케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기      50만+
# 2              2   케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기      50만+
# 3              3   케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기      50만+
# 4              4   케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기      50만+
# ...          ...                             ...       ...
# 2422        2422  케어네이션 - 일감 찾기, 간병인, 동행인, 요양보호사      10만+
# 2423        2423  케어네이션 - 일감 찾기, 간병인, 동행인, 요양보호사      10만+
# 2424        2424  케어네이션 - 일감 찾기, 간병인, 동행인, 요양보호사      10만+
# 2425        2425  케어네이션 - 일감 찾기, 간병인, 동행인, 요양보호사      10만+
# 2426        2426  케어네이션 - 일감 찾기, 간병인, 동행인, 요양보호사      10만+
#
#                       rating  release_date  \
# 0     별표 5개 만점에 4.6개를 받았습니다.  2020. 3. 15.
# 1     별표 5개 만점에 4.6개를 받았습니다.  2020. 3. 15.
# 2     별표 5개 만점에 4.6개를 받았습니다.  2020. 3. 15.
# 3     별표 5개 만점에 4.6개를 받았습니다.  2020. 3. 15.
# 4     별표 5개 만점에 4.6개를 받았습니다.  2020. 3. 15.
# ...                      ...           ...
# 2422  별표 5개 만점에 4.4개를 받았습니다.  2020. 3. 15.
# 2423  별표 5개 만점에 4.4개를 받았습니다.  2020. 3. 15.
# 2424  별표 5개 만점에 4.4개를 받았습니다.  2020. 3. 15.
# 2425  별표 5개 만점에 4.4개를 받았습니다.  2020. 3. 15.
# 2426  별표 5개 만점에 4.4개를 받았습니다.  2020. 3. 15.
#
#                                                    info           reviewer  \
# 0     🤎🤎간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗🤎🤎\n\n👉3...     n Butter Bread
# 1     🤎🤎간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗🤎🤎\n\n👉3...            XXX XXX
# 2     🤎🤎간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗🤎🤎\n\n👉3...                신미경
# 3     🤎🤎간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗🤎🤎\n\n👉3...                백승희
# 4     🤎🤎간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗🤎🤎\n\n👉3...  Jeju life Jaymi's
# ...                                                 ...                ...
# 2422  💙💙간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗💙💙\n\n👉 ...                추유린
# 2423  💙💙간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗💙💙\n\n👉 ...                장주미
# 2424  💙💙간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗💙💙\n\n👉 ...                한옥분
# 2425  💙💙간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗💙💙\n\n👉 ...              해피스마일
# 2426  💙💙간병 · 요양 · 동행 · 가사돌봄까지 모든 헬스케어를 연결하다🔗💙💙\n\n👉 ...            샛노란해바라기
#
#                      stars    review_date  \
# 0     별표 5개 만점에 1개를 받았습니다.    2023년 8월 5일
# 1     별표 5개 만점에 1개를 받았습니다.   2023년 10월 3일
# 2     별표 5개 만점에 1개를 받았습니다.   2023년 9월 27일
# 3     별표 5개 만점에 4개를 받았습니다.   2023년 10월 3일
# 4     별표 5개 만점에 2개를 받았습니다.   2023년 9월 28일
# ...                    ...            ...
# 2422  별표 5개 만점에 4개를 받았습니다.    2021년 9월 6일
# 2423  별표 5개 만점에 5개를 받았습니다.   2021년 8월 16일
# 2424  별표 5개 만점에 5개를 받았습니다.  2020년 10월 19일
# 2425  별표 5개 만점에 5개를 받았습니다.   2021년 8월 30일
# 2426  별표 5개 만점에 5개를 받았습니다.   2021년 8월 21일
#
#                                                 content  rate_int
# 0     네트워크오류라고 나와서 와이파이 끄고 하면 로그인 안되고 일시적인 오류라고 계속 뜹...         1
# 1     카카오로 시작하기로 가입햇는데 로그인후 카카오로 로그인이 안됩니다 계속 튕기고 삭제...         1
# 2     앱열기가 안되네여.. 삭제후 재설치..권한도 설정들어가서 직접했는데도 앱자체가 안열...         1
# 3     카카오로 시작하기가 안됩니다. 크롬에서 카카오로 가입 후 건뱡신청 했는데 어플에서는...         4
# 4     앱 접속할때마다 네트워크가 없다고 떠요. 어떻게 사용하라는건가요? 그리고 간병금액 ...         2
# ...                                                 ...       ...
# 2422                                            앱통장 편해~         4
# 2423                                               좋습니다         5
# 2424                                                좋아요         5
# 2425                                           Good!!😙😙         5
# 2426                                           Good~~^^         5
#
# [2427 rows x 11 columns]

# %%
df_care_only = df_care_only[["title", "reviewer", "review_date", "content", "rate_int"]]
df_care_only[:5]
# Out:
#                            title           reviewer   review_date  \
# 0  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기     n Butter Bread   2023년 8월 5일
# 1  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기            XXX XXX  2023년 10월 3일
# 2  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                신미경  2023년 9월 27일
# 3  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                백승희  2023년 10월 3일
# 4  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기  Jeju life Jaymi's  2023년 9월 28일
#
#                                              content  rate_int
# 0  네트워크오류라고 나와서 와이파이 끄고 하면 로그인 안되고 일시적인 오류라고 계속 뜹...         1
# 1  카카오로 시작하기로 가입햇는데 로그인후 카카오로 로그인이 안됩니다 계속 튕기고 삭제...         1
# 2  앱열기가 안되네여.. 삭제후 재설치..권한도 설정들어가서 직접했는데도 앱자체가 안열...         1
# 3  카카오로 시작하기가 안됩니다. 크롬에서 카카오로 가입 후 건뱡신청 했는데 어플에서는...         4
# 4  앱 접속할때마다 네트워크가 없다고 떠요. 어떻게 사용하라는건가요? 그리고 간병금액 ...         2

# %%
rate_int = [0 if rate_int in range(0,5) else 1 for rate_int in df_care_only['rate_int']]
pos_cnt = len([x for x in rate_int if x==1])
neg_cnt = len([x for x in rate_int if x==0])
print(("긍정비율 : {:.4f}%,".format(pos_cnt/len(rate_int))+" 긍정개수 : {}개".format(pos_cnt)))
print(("부정비율 : {:.4f}%,".format(neg_cnt/len(rate_int))+" 부정개수 : {}개".format(neg_cnt)))
# Out:
# 긍정비율 : 0.7478%, 긍정개수 : 1815개
# 부정비율 : 0.2522%, 부정개수 : 612개

# %%
df_care_only.to_csv('../df_care_only.csv')

# %%
! pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to c:\users\moony\appdata\local\temp\pip-req-build-4o7r2bs4
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit d1e2f93759b1bcc74b6aaa345a62c08701e5546e
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# INFO: pip is looking at multiple versions of pykospacing to determine which version is compatible with other requirements. This could take a while.
#   Running command git clone --filter=blob:none --quiet https://github.com/haven-jeon/PyKoSpacing.git 'C:\Users\moony\AppData\Local\Temp\pip-req-build-4o7r2bs4'
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.9.3 (from pykospacing) (from versions: 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0)
# ERROR: No matching distribution found for tensorflow==2.9.3

# %%
! pip install soynlp
# Out:
# Collecting soynlp
#   Downloading soynlp-0.0.493-py3-none-any.whl (416 kB)
#      ---------------------------------------- 0.0/416.8 kB ? eta -:--:--
#      ------------------------------------  409.6/416.8 kB 12.9 MB/s eta 0:00:01
#      ------------------------------------  409.6/416.8 kB 12.9 MB/s eta 0:00:01
#      ------------------------------------  409.6/416.8 kB 12.9 MB/s eta 0:00:01
#      ------------------------------------  409.6/416.8 kB 12.9 MB/s eta 0:00:01
#      ------------------------------------  409.6/416.8 kB 12.9 MB/s eta 0:00:01
#      -------------------------------------- 416.8/416.8 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.12.1 in c:\users\moony\anaconda3\lib\site-packages (from soynlp) (1.24.3)
# Requirement already satisfied: psutil>=5.0.1 in c:\users\moony\anaconda3\lib\site-packages (from soynlp) (5.9.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\moony\anaconda3\lib\site-packages (from soynlp) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\moony\anaconda3\lib\site-packages (from soynlp) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\moony\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->soynlp) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\moony\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->soynlp) (2.2.0)
# Installing collected packages: soynlp
# Successfully installed soynlp-0.0.493

# %%
! git clone https://github.com/ssut/py-hanspell
# Out:
# Cloning into 'py-hanspell'...

# %%
! git clone https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Cloning into 'PyKoSpacing'...

# %%
import os
os.chdir('../py-hanspell')

# %%
! python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing py_hanspell.egg-info\PKG-INFO
# writing dependency_links to py_hanspell.egg-info\dependency_links.txt
# writing requirements to py_hanspell.egg-info\requires.txt
# writing top-level names to py_hanspell.egg-info\top_level.txt
# reading manifest file 'py_hanspell.egg-info\SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'py_hanspell.egg-info\SOURCES.txt'
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# running build_py
# creating build\bdist.win-amd64\egg
# creating build\bdist.win-amd64\egg\hanspell
# copying build\lib\hanspell\constants.py -> build\bdist.win-amd64\egg\hanspell
# copying build\lib\hanspell\response.py -> build\bdist.win-amd64\egg\hanspell
# copying build\lib\hanspell\spell_checker.py -> build\bdist.win-amd64\egg\hanspell
# copying build\lib\hanspell\__init__.py -> build\bdist.win-amd64\egg\hanspell
# byte-compiling build\bdist.win-amd64\egg\hanspell\constants.py to constants.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\hanspell\response.py to response.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\hanspell\spell_checker.py to spell_checker.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\hanspell\__init__.py to __init__.cpython-311.pyc
# creating build\bdist.win-amd64\egg\EGG-INFO
# copying py_hanspell.egg-info\PKG-INFO -> build\bdist.win-amd64\egg\EGG-INFO
# copying py_hanspell.egg-info\SOURCES.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying py_hanspell.egg-info\dependency_links.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying py_hanspell.egg-info\requires.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying py_hanspell.egg-info\top_level.txt -> build\bdist.win-amd64\egg\EGG-INFO
# creating 'dist\py_hanspell-1.1-py3.11.egg' and adding 'build\bdist.win-amd64\egg' to it
# removing 'build\bdist.win-amd64\egg' (and everything under it)
# Processing py_hanspell-1.1-py3.11.egg
# Removing c:\users\moony\anaconda3\lib\site-packages\py_hanspell-1.1-py3.11.egg
# C:\Users\moony\anaconda3\Lib\site-packages\setuptools\dist.py:745: SetuptoolsDeprecationWarning: Invalid dash-separated options
# !!
#
#         ********************************************************************************
#         Usage of dash-separated 'description-file' will not be supported in future
#         versions. Please use the underscore name 'description_file' instead.
#
#         This deprecation is overdue, please update your project and remove deprecated
#         calls to avoid build errors in the future.
#
#         See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#         ********************************************************************************
#
# !!
#   opt = self.warn_dash_deprecation(opt, section)
# C:\Users\moony\anaconda3\Lib\site-packages\setuptools\_distutils\cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# C:\Users\moony\anaconda3\Lib\site-packages\setuptools\_distutils\cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# zip_safe flag not set; analyzing archive contents...
# error: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'c:\\users\\moony\\anaconda3\\lib\\site-packages\\py_hanspell-1.1-py3.11.egg'

# %%
from pykospacing import Spacing
spacing=Spacing()

# %%
! pip install kss
# Out:
# Collecting kss
#   Downloading kss-4.5.4.tar.gz (79 kB)
#      ---------------------------------------- 0.0/79.1 kB ? eta -:--:--
#      ------------------------------------ --- 71.7/79.1 kB 3.8 MB/s eta 0:00:01
#      ---------------------------------------- 79.1/79.1 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting emoji==1.2.0 (from kss)
#   Downloading emoji-1.2.0-py3-none-any.whl (131 kB)
#      ---------------------------------------- 0.0/131.3 kB ? eta -:--:--
#      -------------------------------------- 131.3/131.3 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: regex in c:\users\moony\anaconda3\lib\site-packages (from kss) (2022.7.9)
# Collecting pecab (from kss)
#   Downloading pecab-1.0.8.tar.gz (26.4 MB)
#      ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#      - -------------------------------------- 0.8/26.4 MB 27.1 MB/s eta 0:00:01
#      --- ------------------------------------ 2.4/26.4 MB 31.0 MB/s eta 0:00:01
#      ------- -------------------------------- 4.8/26.4 MB 38.6 MB/s eta 0:00:01
#      ----------- ---------------------------- 7.6/26.4 MB 43.9 MB/s eta 0:00:01
#      -------------- ------------------------ 10.1/26.4 MB 45.9 MB/s eta 0:00:01
#      ------------------ -------------------- 12.8/26.4 MB 54.4 MB/s eta 0:00:01
#      ----------------------- --------------- 15.6/26.4 MB 59.8 MB/s eta 0:00:01
#      --------------------------- ----------- 18.4/26.4 MB 59.5 MB/s eta 0:00:01
#      ------------------------------- ------- 21.2/26.4 MB 59.5 MB/s eta 0:00:01
#      ---------------------------------- ---- 23.1/26.4 MB 59.8 MB/s eta 0:00:01
#      ---------------------------------- ---- 23.1/26.4 MB 59.8 MB/s eta 0:00:01
#      ---------------------------------- ---- 23.1/26.4 MB 59.8 MB/s eta 0:00:01
#      ---------------------------------- ---- 23.1/26.4 MB 59.8 MB/s eta 0:00:01
#      ---------------------------------- ---- 23.1/26.4 MB 59.8 MB/s eta 0:00:01
#      ------------------------------------- - 25.5/26.4 MB 27.3 MB/s eta 0:00:01
#      --------------------------------------  26.4/26.4 MB 25.2 MB/s eta 0:00:01
#      --------------------------------------  26.4/26.4 MB 25.2 MB/s eta 0:00:01
#      --------------------------------------  26.4/26.4 MB 25.2 MB/s eta 0:00:01
#      --------------------------------------- 26.4/26.4 MB 18.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: networkx in c:\users\moony\anaconda3\lib\site-packages (from kss) (3.1)
# Requirement already satisfied: numpy in c:\users\moony\anaconda3\lib\site-packages (from pecab->kss) (1.24.3)
# Requirement already satisfied: pyarrow in c:\users\moony\anaconda3\lib\site-packages (from pecab->kss) (11.0.0)
# Requirement already satisfied: pytest in c:\users\moony\anaconda3\lib\site-packages (from pecab->kss) (7.4.0)
# Requirement already satisfied: iniconfig in c:\users\moony\anaconda3\lib\site-packages (from pytest->pecab->kss) (1.1.1)
# Requirement already satisfied: packaging in c:\users\moony\anaconda3\lib\site-packages (from pytest->pecab->kss) (23.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\moony\anaconda3\lib\site-packages (from pytest->pecab->kss) (1.0.0)
# Requirement already satisfied: colorama in c:\users\moony\anaconda3\lib\site-packages (from pytest->pecab->kss) (0.4.6)
# Building wheels for collected packages: kss, pecab
#   Building wheel for kss (setup.py): started
#   Building wheel for kss (setup.py): finished with status 'done'
#   Created wheel for kss: filename=kss-4.5.4-py3-none-any.whl size=54785 sha256=24c2e1c0edda110a3994e40327ea532a20064447c963a943a01910155b06aeb1
#   Stored in directory: c:\users\moony\appdata\local\pip\cache\wheels\ca\b1\87\4956cfbe83e7bb718e2363fdaa4581cdfebc4a67baad48a7d3
#   Building wheel for pecab (setup.py): started
#   Building wheel for pecab (setup.py): finished with status 'done'
#   Created wheel for pecab: filename=pecab-1.0.8-py3-none-any.whl size=26646701 sha256=07b4a319da3eb6555e2429d619cf46d1667591f706bd06f9247dcb0fa3d72ee8
#   Stored in directory: c:\users\moony\appdata\local\pip\cache\wheels\c9\0d\97\ca2bb361e44a80f4c63efe6f6438ff903fd1ab5640eedabc1b
# Successfully built kss pecab
# Installing collected packages: emoji, pecab, kss
# Successfully installed emoji-1.2.0 kss-4.5.4 pecab-1.0.8
# DEPRECATION: Loading egg at c:\users\moony\anaconda3\lib\site-packages\argparse-1.4.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\moony\anaconda3\lib\site-packages\pykospacing-0.5-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\moony\anaconda3\lib\site-packages\py_hanspell-1.1-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %%
import kss

# %%
! pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#       --------------------------------------- 0.4/19.4 MB 12.6 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/19.4 MB 13.3 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/19.4 MB 13.3 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/19.4 MB 13.3 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/19.4 MB 13.3 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/19.4 MB 13.3 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/19.4 MB 13.3 MB/s eta 0:00:02
#      -- ------------------------------------- 1.3/19.4 MB 3.5 MB/s eta 0:00:06
#      ---- ----------------------------------- 2.4/19.4 MB 5.7 MB/s eta 0:00:03
#      ------ --------------------------------- 3.1/19.4 MB 7.2 MB/s eta 0:00:03
#      ------ --------------------------------- 3.1/19.4 MB 7.2 MB/s eta 0:00:03
#      -------- ------------------------------- 4.0/19.4 MB 7.1 MB/s eta 0:00:03
#      ------------ --------------------------- 6.3/19.4 MB 10.3 MB/s eta 0:00:02
#      ------------------ --------------------- 9.1/19.4 MB 13.8 MB/s eta 0:00:01
#      ------------------- -------------------- 9.4/19.4 MB 14.0 MB/s eta 0:00:01
#      ------------------- -------------------- 9.4/19.4 MB 14.0 MB/s eta 0:00:01
#      ------------------- -------------------- 9.4/19.4 MB 14.0 MB/s eta 0:00:01
#      ------------------- -------------------- 9.4/19.4 MB 14.0 MB/s eta 0:00:01
#      ------------------- -------------------- 9.4/19.4 MB 14.0 MB/s eta 0:00:01
#      ------------------- -------------------- 9.4/19.4 MB 14.0 MB/s eta 0:00:01
#      ------------------------ -------------- 12.1/19.4 MB 17.2 MB/s eta 0:00:01
#      ---------------------------- ---------- 14.3/19.4 MB 21.9 MB/s eta 0:00:01
#      --------------------------------- ----- 16.5/19.4 MB 21.9 MB/s eta 0:00:01
#      ------------------------------------- - 18.7/19.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------- - 18.9/19.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------- - 18.9/19.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------- - 18.9/19.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------- - 18.9/19.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------- - 18.9/19.4 MB 21.1 MB/s eta 0:00:01
#      --------------------------------------  19.0/19.4 MB 13.6 MB/s eta 0:00:01
#      --------------------------------------  19.4/19.4 MB 13.6 MB/s eta 0:00:01
#      --------------------------------------  19.4/19.4 MB 13.6 MB/s eta 0:00:01
#      --------------------------------------- 19.4/19.4 MB 11.7 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.4.1-cp311-cp311-win_amd64.whl (345 kB)
#      ---------------------------------------- 0.0/345.1 kB ? eta -:--:--
#      -------------------------------------- 345.1/345.1 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in c:\users\moony\anaconda3\lib\site-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in c:\users\moony\anaconda3\lib\site-packages (from konlpy) (1.24.3)
# Requirement already satisfied: packaging in c:\users\moony\anaconda3\lib\site-packages (from JPype1>=0.7.0->konlpy) (23.0)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0
# DEPRECATION: Loading egg at c:\users\moony\anaconda3\lib\site-packages\argparse-1.4.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\moony\anaconda3\lib\site-packages\pykospacing-0.5-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\moony\anaconda3\lib\site-packages\py_hanspell-1.1-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %%
from konlpy.tag import Okt
from konlpy.tag import Kkma

# %%
import re

# %%
spacing("사람들은 왜 이가빠지기 시작한거에요? 어떤거를 섭취했ㅆ길래?")
# Out:
# '사람들은 왜 이가 빠지기 시작한 거에요? 어떤 거를 섭취했ㅆ길래?'

# %%
reviews_list = list(df_care_only['content'])
reviews_list[:5]
# Out:
# ['네트워크오류라고 나와서 와이파이 끄고 하면 로그인 안되고 일시적인 오류라고 계속 뜹니다. 간병인 결정하고 결제해야 하는데 주말이라 고객센터도 전화안되고 어떡하죠? 빨리 해결되기를 바랍니다.',
#  '카카오로 시작하기로 가입햇는데 로그인후 카카오로 로그인이 안됩니다 계속 튕기고 삭제후 재설치 해도 계속 튕깁니다 왜이런가요 아니 이거 로그인이 안되니 회원 탈퇴도 안되고 재가입도 안되고 뭘 할수있는게 아무것도 없네',
#  '앱열기가 안되네여.. 삭제후 재설치..권한도 설정들어가서 직접했는데도 앱자체가 안열려요...',
#  '카카오로 시작하기가 안됩니다. 크롬에서 카카오로 가입 후 건뱡신청 했는데 어플에서는 카카오로 시작하기가 아예 안돼서 난처하네요. 간병서비스 신청하는 것 자체는 유용합니다.',
#  '앱 접속할때마다 네트워크가 없다고 떠요. 어떻게 사용하라는건가요? 그리고 간병금액 상한선 같은건 없나요? 하루 일당 30만원도 넘게 지원하는 간병인도 있는데 그냥 되는대로 막 부르는건지요..']

# %%
len(reviews_list)
# Out:
# 2427

# %%
reviews=' '.join(df_care_only['content'])
reviews[:500]
# Out:
# '네트워크오류라고 나와서 와이파이 끄고 하면 로그인 안되고 일시적인 오류라고 계속 뜹니다. 간병인 결정하고 결제해야 하는데 주말이라 고객센터도 전화안되고 어떡하죠? 빨리 해결되기를 바랍니다. 카카오로 시작하기로 가입햇는데 로그인후 카카오로 로그인이 안됩니다 계속 튕기고 삭제후 재설치 해도 계속 튕깁니다 왜이런가요 아니 이거 로그인이 안되니 회원 탈퇴도 안되고 재가입도 안되고 뭘 할수있는게 아무것도 없네 앱열기가 안되네여.. 삭제후 재설치..권한도 설정들어가서 직접했는데도 앱자체가 안열려요... 카카오로 시작하기가 안됩니다. 크롬에서 카카오로 가입 후 건뱡신청 했는데 어플에서는 카카오로 시작하기가 아예 안돼서 난처하네요. 간병서비스 신청하는 것 자체는 유용합니다. 앱 접속할때마다 네트워크가 없다고 떠요. 어떻게 사용하라는건가요? 그리고 간병금액 상한선 같은건 없나요? 하루 일당 30만원도 넘게 지원하는 간병인도 있는데 그냥 되는대로 막 부르는건지요.. 서비스는 유용한데 앱자체 오류가 너'

# %%
review_spaced = spacing(reviews)

# %%
review_spaced[:500]
# Out:
# '네트워크 오류라고 나와서 와이파이 끄고 하면 로그인 안 되고 일시적인 오류라고 계속 뜹니다. 간병인 결정하고 결제해야 하는데 주말이라 고객센터도 전화 안 되고 어 떡하죠? 빨리 해결되기를 바랍니다. 카카오로 시작하기로 가입 햇는데 로그인 후 카카오로 로그인이 안 됩니다 계속 튕기고 삭제 후 재 설치 해도 계속 튕깁니다 왜 이런 가요 아니 이 거 로그인이 안 되니 회원 탈퇴도 안 되고 재가입도 안 되고 뭘 할 수 있는 게 아무것도 없네 앱 열기가 안 되네 여.. 삭제 후 재 설치..권한도 설정 들어가서 직접 했는데도 앱 자체가 안 열려요... 카카오로 시작하기가 안 됩니다. 크롬에서 카카오로 가입 후 건 뱡 신청 했는데 어플에서는 카카오로 시작하기가 아예 안 돼서 난처하네요. 간병 서비스 신청하는 것 자체는 유용합니다. 앱 접속할 때마다 네트워크가 없다고 떠요.  어떻게 사용하라는 건가요? 그리고 간병 금액 상한선 같은 건 없나요? 하루 일 당 30만원도 넘게 지원하는 간병인도 있는데'

# %%
# from hanspell import spell_checker
# review_spelled = review_spaced.check(sent)
# hanspell_sent = review_spelled.checked
# hanspell_sent[:500]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 from hanspell import spell_checker
#       2 review_spelled = review_spaced.check(sent)
#       3 hanspell_sent = review_spelled.checked
#
# ModuleNotFoundError: No module named 'hanspell'

# %%
# ! pip install mecab
# Out:
# Collecting mecab
#   Downloading mecab-0.996.3.tar.gz (62 kB)
#      ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#      ---------------------------------------- 62.6/62.6 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# DEPRECATION: Loading egg at c:\users\moony\anaconda3\lib\site-packages\argparse-1.4.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\moony\anaconda3\lib\site-packages\pykospacing-0.5-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\moony\anaconda3\lib\site-packages\py_hanspell-1.1-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [6 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\moony\AppData\Local\Temp\pip-install-p92j_3yi\mecab_ccbc6f0b884a476fa4202c092e73ba96\setup.py", line 35, in <module>
#       raise RuntimeError(PY64WIN_ERROR)
#   RuntimeError: Please install MeCab 64-bit binary: https://github.com/ikegami-yukino/mecab/releases
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# from mecab import MeCab
# mecab = MeCab()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 from mecab import MeCab
#       2 mecab = MeCab()
#
# ModuleNotFoundError: No module named 'mecab'

# %%
okt = Okt()

words = ' '.join(df_care_only['content'].tolist())
words = okt.morphs(words, stem=True)
words[:20]
# Out:
# ['네트워크',
#  '오류',
#  '라고',
#  '나오다',
#  '와이파이',
#  '끄다',
#  '하다',
#  '로그인',
#  '안되다',
#  '일시',
#  '적',
#  '인',
#  '오류',
#  '라고',
#  '계속',
#  '뜨다',
#  '.',
#  '간병인',
#  '결정',
#  '하고']

# %%
len(words)
# Out:
# 39805

# %%
replace_list = pd.read_excel('../replace_list.xlsx')
replace_list[40:50]
# Out:
#    before_replacement after_replacement
# 40                 컵양                컵량
# 41                컵 량                컵량
# 42              컬처 랜드              컬쳐랜드
# 43                 캐시               포인트
# 44                 캐시               포인트
# 45                 캐쉬               포인트
# 46                 후기                리뷰
# 47              칼로리 양              칼로리량
# 48              칼로리 량              칼로리량
# 49                카톡방               채팅방

# %%
with open('../stopwords.txt', 'r', encoding = 'utf-8') as f:
    list_file = f.readlines()
stopwords = list_file[0].split(",")
remove_stopwords = [x for x in words if x not in stopwords]
len(remove_stopwords)
# Out:
# 24976

# %%
df_care_only['spaced_review'] = df_care_only['content'].apply(spacing)
df_care_only[:5]
# Out:
# C:\Users\moony\AppData\Local\Temp\ipykernel_2928\3289994075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_care_only['spaced_review'] = df_care_only['content'].apply(spacing)
#                            title           reviewer   review_date  \
# 0  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기     n Butter Bread   2023년 8월 5일
# 1  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기            XXX XXX  2023년 10월 3일
# 2  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                신미경  2023년 9월 27일
# 3  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                백승희  2023년 10월 3일
# 4  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기  Jeju life Jaymi's  2023년 9월 28일
#
#                                              content  rate_int  \
# 0  네트워크오류라고 나와서 와이파이 끄고 하면 로그인 안되고 일시적인 오류라고 계속 뜹...         1
# 1  카카오로 시작하기로 가입햇는데 로그인후 카카오로 로그인이 안됩니다 계속 튕기고 삭제...         1
# 2  앱열기가 안되네여.. 삭제후 재설치..권한도 설정들어가서 직접했는데도 앱자체가 안열...         1
# 3  카카오로 시작하기가 안됩니다. 크롬에서 카카오로 가입 후 건뱡신청 했는데 어플에서는...         4
# 4  앱 접속할때마다 네트워크가 없다고 떠요. 어떻게 사용하라는건가요? 그리고 간병금액 ...         2
#
#                                        spaced_review
# 0  네트워크 오류라고 나와서 와이파이 끄고 하면 로그인 안 되고 일시적인 오류라고 계속...
# 1  카카오로 시작하기로 가입 햇는데 로그인 후 카카오로 로그인이 안 됩니다 계속 튕기고...
# 2  앱 열기가 안 되네 여.. 삭제 후 재 설치..권한도 설정 들어가서 직접 했는데도 ...
# 3  카카오로 시작하기가 안 됩니다. 크롬에서 카카오로 가입 후 건 뱡 신청 했는데 어플...
# 4  앱 접속할 때마다 네트워크가 없다고 떠요. 어떻게 사용하라는 건가요? 그리고 간병 ...

# %%
def replace_word(tokenized_review):
    replaced_review = tokenized_review
    for i in range(len(replace_list['before_replacement'])):
        try:
            if replace_list['before_replacement'][i] in replaced_review:
                replaced_review = replaced_review.replace(replace_list['before_replacement'][i], replace_list['after_replacement'][i])
        except Exception as e:
            # print(f"Error 발생 / 에러명: {e}")
            pass
    return replaced_review

# %%
one_words = [x for x in words if len(x)==1]
one_words
# Out:
# ['적',
#  '인',
#  '.',
#  '도',
#  '?',
#  '.',
#  '로',
#  '햇',
#  '로',
#  '이',
#  '고',
#  '후',
#  '재',
#  '다',
#  '왜',
#  '이',
#  '거',
#  '이',
#  '도',
#  '재',
#  '도',
#  '뭘',
#  '것',
#  '도',
#  '앱',
#  '가',
#  '네',
#  '여',
#  '후',
#  '재',
#  '도',
#  '앱',
#  '가',
#  '안',
#  '로',
#  '.',
#  '로',
#  '후',
#  '로',
#  '안',
#  '.',
#  '것',
#  '는',
#  '.',
#  '앱',
#  '때',
#  '가',
#  '.',
#  '하',
#  '요',
#  '?',
#  '?',
#  '도',
#  '도',
#  '막',
#  '는',
#  '앱',
#  '가',
#  '.',
#  '1',
#  '.',
#  '내',
#  '때',
#  '가',
#  '뜸',
#  '(',
#  ',',
#  '면',
#  '.',
#  ')',
#  '2',
#  '.',
#  '이',
#  '-',
#  '로',
#  '뜸',
#  '.',
#  '로',
#  '.',
#  '은',
#  '로',
#  '로',
#  '뜸',
#  '.',
#  '3',
#  '.',
#  '수',
#  '.',
#  '-',
#  '이',
#  ',',
#  '다',
#  '동',
#  '일',
#  '이',
#  '.',
#  '이',
#  '별',
#  '1',
#  '앱',
#  '은',
#  '도',
#  '움',
#  '.',
#  '에',
#  '.',
#  '이',
#  '후',
#  '?',
#  '네',
#  '요',
#  '님',
#  '이',
#  '때',
#  '엔',
#  '이',
#  '잘',
#  '대',
#  '돈',
#  '이',
#  '도',
#  '안',
#  '앱',
#  '을',
#  '요',
#  '.',
#  '을',
#  '건',
#  '를',
#  '적',
#  '을',
#  '이',
#  '것',
#  '.',
#  '분',
#  '왜',
#  '를',
#  '.',
#  '도',
#  '심',
#  '이',
#  '분',
#  '.',
#  '.',
#  '서',
#  '구',
#  '듯',
#  '.',
#  '에',
#  '점',
#  '은',
#  '점',
#  '.',
#  '에',
#  '구',
#  '때',
#  '는',
#  '식',
#  '잘',
#  '땐',
#  '원',
#  '의',
#  '을',
#  '표',
#  '구',
#  '적',
#  '을',
#  '야',
#  '로',
#  '는',
#  '분',
#  '들',
#  '만',
#  '분',
#  '이',
#  '!',
#  '볼',
#  '수',
#  '수',
#  ';',
#  '!',
#  '는',
#  '못',
#  '가',
#  '하',
#  '.',
#  '라',
#  '적',
#  '인',
#  '도',
#  '~',
#  '가',
#  '한',
#  '게',
#  '에',
#  '로',
#  '구',
#  '애',
#  '요',
#  '!',
#  '도',
#  '다',
#  '수',
#  '이',
#  '.',
#  '때',
#  ',',
#  '을',
#  '도',
#  '잘',
#  '가',
#  '구',
#  '때',
#  '에',
#  '구',
#  '.',
#  '저',
#  '도',
#  '을',
#  '번',
#  '.',
#  '씩',
#  '때',
#  '.',
#  '이',
#  '을',
#  '딱',
#  '.',
#  '제',
#  '가',
#  '을',
#  '이',
#  '더',
#  '.',
#  '한',
#  '안',
#  '를',
#  '을',
#  '구',
#  '다',
#  '.',
#  '를',
#  '을',
#  '도',
#  '!',
#  '!',
#  '히',
#  '다',
#  '수',
#  '.',
#  '도',
#  '고',
#  ',',
#  '도',
#  '.',
#  '야',
#  '뭘',
#  '.',
#  '앱',
#  ',',
#  '.',
#  '은',
#  '가',
#  '앱',
#  '앱',
#  '이',
#  '또',
#  '쭉',
#  '로',
#  '이',
#  '이',
#  '를',
#  '과',
#  '이',
#  '.',
#  '번',
#  '!',
#  '앱',
#  '가',
#  '에',
#  '것',
#  '이',
#  '한',
#  '분',
#  '이',
#  '.',
#  '을',
#  '구',
#  '를',
#  '헤',
#  '을',
#  '.',
#  '이',
#  '이',
#  '을',
#  '서',
#  '을',
#  '을',
#  'ㅠ',
#  '잘',
#  '.',
#  '별',
#  ',',
#  '이',
#  '이',
#  '왜',
#  '내',
#  '.',
#  '과',
#  '그',
#  '외',
#  '내',
#  '폰',
#  '에',
#  '을',
#  '이',
#  '그',
#  '가',
#  '왜',
#  '은',
#  '?',
#  '의',
#  '에',
#  '을',
#  '.',
#  '것',
#  '를',
#  '히',
#  '못',
#  '좀',
#  '.',
#  '를',
#  '이',
#  '를',
#  '요',
#  '?',
#  '의',
#  '와',
#  '는',
#  '.',
#  '에',
#  '이',
#  '.',
#  '성',
#  '이',
#  '수',
#  '!',
#  '전',
#  '에',
#  '에',
#  '구',
#  '.',
#  '을',
#  '구',
#  '.',
#  '은',
#  '에',
#  '.',
#  '이',
#  '안',
#  '을',
#  '이',
#  '.',
#  '들',
#  '도',
#  '에',
#  '도',
#  '제',
#  '맘',
#  '에',
#  '을',
#  '이',
#  '을',
#  '접',
#  '의',
#  '을',
#  '분',
#  '만',
#  '님',
#  '과',
#  '.',
#  '가',
#  '분',
#  '을',
#  '딱',
#  '에',
#  '구',
#  '일',
#  '일',
#  '.',
#  '이',
#  '을',
#  '건',
#  '이',
#  '.',
#  '안',
#  '만',
#  '에',
#  '도',
#  '못',
#  '.',
#  '분',
#  '이',
#  '을',
#  '이',
#  '.',
#  '에',
#  '안',
#  '수',
#  '.',
#  '도',
#  '걸',
#  '에',
#  '돈',
#  '은',
#  '가',
#  '.',
#  '는',
#  '이',
#  '돈',
#  '이',
#  '만',
#  '이',
#  '젠',
#  '로',
#  '이',
#  '.',
#  '앱',
#  '님',
#  '~',
#  '.',
#  '!',
#  '이',
#  '에',
#  '도',
#  '이',
#  '.',
#  '나',
#  '데',
#  '는',
#  '도',
#  '만',
#  ',',
#  '도',
#  '앱',
#  '수',
#  '중',
#  '을',
#  '.',
#  '의',
#  '를',
#  '수',
#  ',',
#  '분',
#  '이',
#  '만',
#  '.',
#  '이',
#  '도',
#  '이',
#  '그',
#  '중',
#  '에',
#  '골',
#  '로',
#  '로',
#  '곳',
#  '은',
#  '도',
#  '잘',
#  '이',
#  '명',
#  '을',
#  '의',
#  '폭',
#  '이',
#  '!',
#  '것',
#  '도',
#  '타',
#  '도',
#  '에',
#  '을',
#  '것',
#  '.',
#  '라',
#  '별',
#  '점',
#  '등',
#  '을',
#  '수',
#  '에',
#  '이',
#  '~',
#  '이',
#  '.',
#  '에',
#  '.',
#  '분',
#  '이',
#  '분',
#  '이',
#  '이',
#  '구',
#  '.',
#  '과',
#  '를',
#  '이',
#  '.',
#  '.',
#  '상',
#  '적',
#  '을',
#  '이',
#  '.',
#  '나',
#  '이',
#  '수',
#  '의',
#  '도',
#  '것',
#  '도',
#  '이',
#  '보',
#  '.',
#  '분',
#  '이',
#  '이',
#  '이',
#  '이',
#  '를',
#  '.',
#  '더',
#  '구',
#  '로',
#  '구',
#  '.',
#  '은',
#  '이',
#  '죠',
#  '가',
#  '이',
#  '이',
#  ',',
#  '이',
#  '것',
#  '만',
#  '면',
#  '탑',
#  '.',
#  '는',
#  '.',
#  '과',
#  '을',
#  '은',
#  '이',
#  '.',
#  '근',
#  '종',
#  '를',
#  '번',
#  '말',
#  '을',
#  '.',
#  '도',
#  '.',
#  '때',
#  '옆',
#  '도',
#  '고',
#  '가',
#  '.',
#  '에',
#  '.',
#  '!',
#  '말',
#  '글',
#  '이',
#  '더',
#  '다',
#  '만',
#  '가',
#  '저',
#  '의',
#  '을',
#  '수',
#  '~',
#  '도',
#  '그',
#  '점',
#  '은',
#  '것',
#  '이',
#  '이',
#  '가',
#  '구',
#  '적',
#  '을',
#  '구',
#  '로',
#  '말',
#  '말',
#  '뭐',
#  '재',
#  '하',
#  '면',
#  '😄',
#  '에',
#  '을',
#  '못',
#  '때',
#  '만',
#  '.',
#  '구',
#  '구',
#  '가',
#  '.',
#  '비',
#  '가',
#  '도',
#  '도',
#  '안',
#  '만',
#  '들',
#  '이',
#  '좀',
#  '가',
#  '가',
#  '.',
#  '을',
#  '구',
#  '때',
#  '가',
#  '!',
#  '분',
#  '이',
#  '의',
#  '가',
#  '이',
#  '젠',
#  '수',
#  '에',
#  '이',
#  '거',
#  '.',
#  '가',
#  '제',
#  '가',
#  '옆',
#  '에',
#  '분',
#  '은',
#  '.',
#  '구',
#  '분',
#  '들',
#  '도',
#  '.',
#  '로',
#  '.',
#  '와',
#  '을',
#  '다',
#  '이',
#  '.',
#  '.',
#  '이',
#  '감',
#  '이',
#  '때',
#  '.',
#  '분',
#  '이',
#  '잘',
#  '.',
#  '맘',
#  '수',
#  '.',
#  '점',
#  '은',
#  '앱',
#  '이',
#  '.',
#  '들',
#  '을',
#  '.',
#  '가',
#  '.',
#  '을',
#  '번',
#  '구',
#  '분',
#  '건',
#  '운',
#  ',',
#  '거',
#  '에',
#  '분',
#  '곳',
#  '이',
#  '.',
#  '이',
#  '저',
#  '한',
#  '테',
#  '는',
#  '과',
#  '을',
#  '도',
#  '도',
#  '구',
#  '답',
#  '인',
#  '듯',
#  '저',
#  '도',
#  '옆',
#  '분',
#  '저',
#  '는',
#  '분',
#  '을',
#  '.',
#  '에',
#  '지',
#  '에',
#  '은',
#  '가',
#  '.',
#  '!',
#  '은',
#  '구',
#  '.',
#  '앞',
#  '더',
#  '수',
#  '인',
#  '것',
#  '을',
#  '로',
#  '이',
#  '요',
#  '.',
#  '를',
#  '.',
#  '을',
#  '잘',
#  '에',
#  '오',
#  '은',
#  '가',
#  '좀',
#  '에',
#  '또',
#  '고',
#  '가',
#  '분',
#  '구',
#  '이',
#  '도',
#  '와',
#  '.',
#  '제',
#  '가',
#  '이',
#  '이',
#  '.',
#  '만',
#  '.',
#  '구',
#  '수',
#  '!',
#  '가',
#  '좀',
#  '분',
#  '들',
#  '은',
#  '것',
#  '.',
#  '을',
#  '가',
#  '더',
#  '것',
#  '타',
#  '를',
#  '님',
#  '.',
#  '가',
#  '다',
#  '.',
#  '.',
#  '저',
#  '도',
#  '!',
#  '가',
#  '이',
#  '을',
#  '번',
#  '전',
#  '만',
#  '덜',
#  '분',
#  '이',
#  '일',
#  '을',
#  '못',
#  '한',
#  '제',
#  '가',
#  '그',
#  '~',
#  '을',
#  '.',
#  '이',
#  '을',
#  '구',
#  '수',
#  '.',
#  '에',
#  '.',
#  '.',
#  '구',
#  '에',
#  '를',
#  '와',
#  '.',
#  '은',
#  '만',
#  '적',
#  '내',
#  '가',
#  '을',
#  '수',
#  '번',
#  '을',
#  '구',
#  '.',
#  '로',
#  '구',
#  '게',
#  '더',
#  '.',
#  '은',
#  '를',
#  ',',
#  '는',
#  '의',
#  '을',
#  '수',
#  '이',
#  '수',
#  '밖',
#  '이',
#  '뭐',
#  '지',
#  '이',
#  '을',
#  '가',
#  '더',
#  '구',
#  '!',
#  '.',
#  '구',
#  '때',
#  '곳',
#  '덴',
#  '가',
#  '~',
#  '관',
#  '한',
#  '도',
#  '이',
#  '.',
#  '구',
#  '~',
#  '굿',
#  '땐',
#  '에',
#  '을',
#  '구',
#  '들',
#  '도',
#  '로',
#  '구',
#  '구',
#  '을',
#  '수',
#  '앱',
#  '돈',
#  '를',
#  '로',
#  '.',
#  '적',
#  '인',
#  '면',
#  '수',
#  '.',
#  '비',
#  '전',
#  '에',
#  '과',
#  '쯤',
#  '수',
#  '~',
#  '그',
#  '이',
#  '.',
#  '분',
#  '은',
#  '것',
#  '구',
#  '이',
#  '에',
#  '랑',
#  '도',
#  '더',
#  '가',
#  '.',
#  '에',
#  '.',
#  '이',
#  '.',
#  '은',
#  '.',
#  '가',
#  '.',
#  '분',
#  '이',
#  '은',
#  '인',
#  '것',
#  '.',
#  '수',
#  '것',
#  ',',
#  '!',
#  '1',
#  '가',
#  '도',
#  '제',
#  '가',
#  '로',
#  '이',
#  '을',
#  '로',
#  '도',
#  '구',
#  '개',
#  '도',
#  '에',
#  '한',
#  '~',
#  'S',
#  '중',
#  '가',
#  '을',
#  '주',
#  '을',
#  '구',
#  '로',
#  '것',
#  '도',
#  '이',
#  '하',
#  '~',
#  '이',
#  '도',
#  '이',
#  '적',
#  '구',
#  '수',
#  '.',
#  '도',
#  '제',
#  '가',
#  '를',
#  '이',
#  '때',
#  '구',
#  '가',
#  '제',
#  '가',
#  '중',
#  '을',
#  '못',
#  '을',
#  '구',
#  '를',
#  '로',
#  '구',
#  '이',
#  '올',
#  '에',
#  '의',
#  '을',
#  '이',
#  '적',
#  '맘',
#  '을',
#  '앱',
#  ...]

# %%
ft = Counter(one_words).most_common()
ft
# Out:
# [('이', 1212),
#  ('.', 865),
#  ('을', 570),
#  ('에', 552),
#  ('도', 550),
#  ('가', 539),
#  ('구', 469),
#  ('~', 354),
#  ('분', 352),
#  ('수', 320),
#  ('앱', 318),
#  ('를', 272),
#  ('것', 235),
#  ('은', 228),
#  ('일', 224),
#  ('로', 182),
#  ('!', 161),
#  ('들', 147),
#  ('안', 136),
#  ('는', 136),
#  ('요', 132),
#  ('때', 128),
#  ('더', 127),
#  ('다', 120),
#  (',', 108),
#  ('만', 107),
#  ('잘', 105),
#  ('저', 103),
#  ('서', 91),
#  ('게', 91),
#  ('적', 82),
#  ('한', 81),
#  ('제', 81),
#  ('비', 79),
#  ('좀', 77),
#  ('님', 71),
#  ('거', 67),
#  ('?', 61),
#  ('고', 61),
#  ('의', 61),
#  ('알', 57),
#  ('중', 56),
#  ('인', 47),
#  ('내', 41),
#  ('점', 40),
#  ('못', 40),
#  ('전', 39),
#  ('번', 37),
#  ('과', 36),
#  ('곳', 36),
#  ('말', 35),
#  ('그', 34),
#  ('랑', 34),
#  ('ㅎ', 32),
#  ('꼭', 32),
#  ('하', 30),
#  ('와', 30),
#  ('돈', 28),
#  ('볼', 28),
#  ('라', 28),
#  ('니', 28),
#  ('개', 25),
#  ('네', 24),
#  ('별', 24),
#  ('엔', 24),
#  ('앞', 23),
#  ('딱', 22),
#  ('또', 22),
#  ('굿', 22),
#  ('날', 22),
#  ('면', 21),
#  ('젠', 21),
#  ('나', 20),
#  ('어', 20),
#  ('여', 19),
#  ('듯', 19),
#  ('후', 17),
#  ('건', 17),
#  ('애', 17),
#  ('데', 17),
#  ('골', 17),
#  ('보', 17),
#  ('뭐', 17),
#  ('지', 17),
#  ('왜', 16),
#  ('대', 16),
#  ('야', 16),
#  ('줄', 16),
#  ('맘', 15),
#  ('햇', 14),
#  ('재', 14),
#  ('걸', 14),
#  ('타', 14),
#  ('집', 14),
#  ('5', 13),
#  ('간', 12),
#  ('해', 12),
#  ('두', 12),
#  ('끝', 12),
#  ('👍', 12),
#  ('원', 11),
#  ('씩', 11),
#  ('옆', 11),
#  ('께', 11),
#  ('쭉', 10),
#  ('꽤', 10),
#  ('힘', 10),
#  ('함', 10),
#  ('심', 9),
#  ('명', 9),
#  ('운', 9),
#  ('시', 9),
#  ('첨', 9),
#  ('1', 8),
#  ('3', 8),
#  ('땐', 8),
#  ('글', 8),
#  ('주', 8),
#  ('속', 8),
#  ('늘', 8),
#  ('위', 8),
#  ('정', 8),
#  ('ㅋ', 8),
#  ('2', 7),
#  ('ㅠ', 7),
#  ('죠', 7),
#  ('관', 7),
#  ('몇', 7),
#  ('휴', 7),
#  ('강', 7),
#  ('달', 7),
#  ('몸', 7),
#  ('히', 6),
#  ('폰', 6),
#  ('성', 6),
#  ('오', 6),
#  ('뿐', 6),
#  ('쪽', 6),
#  ('사', 6),
#  ('용', 6),
#  ('든', 6),
#  ('아', 6),
#  ('빨', 6),
#  ('^', 6),
#  ('(', 5),
#  (')', 5),
#  ('움', 5),
#  ('외', 5),
#  ('덜', 5),
#  ('째', 5),
#  ('역', 5),
#  ('암', 5),
#  ('♥', 5),
#  ('매', 5),
#  ('짱', 5),
#  ('선', 5),
#  ('울', 5),
#  ('음', 5),
#  ('열', 5),
#  ('복', 5),
#  ('짐', 5),
#  ('뭘', 4),
#  ('뜸', 4),
#  (';', 4),
#  ('등', 4),
#  ('감', 4),
#  ('봣', 4),
#  ('티', 4),
#  ('셧', 4),
#  ('싹', 4),
#  ('무', 4),
#  ('세', 4),
#  ('바', 4),
#  ('첫', 4),
#  ('자', 4),
#  ('남', 4),
#  ('쉬', 4),
#  ('ㅡ', 4),
#  ('★', 4),
#  ('♡', 4),
#  ('폭', 3),
#  ('상', 3),
#  ('테', 3),
#  ('올', 3),
#  ('터', 3),
#  ('…', 3),
#  ('직', 3),
#  ('기', 3),
#  ('문', 3),
#  ('케', 3),
#  ('디', 3),
#  ('뻔', 3),
#  ('래', 3),
#  ('값', 3),
#  ('결', 3),
#  ('장', 3),
#  ('웟', 3),
#  ('공', 3),
#  ('셨', 3),
#  ('약', 3),
#  ('손', 3),
#  ('통', 3),
#  ('영', 3),
#  ('눈', 3),
#  ('·', 3),
#  ('콜', 3),
#  ('-', 2),
#  ('식', 2),
#  ('접', 2),
#  ('답', 2),
#  ('밖', 2),
#  ('덴', 2),
#  ('팀', 2),
#  ('필', 2),
#  ('살', 2),
#  ('방', 2),
#  ('너', 2),
#  ('뒤', 2),
#  ('ㅣ', 2),
#  ('혹', 2),
#  ('닥', 2),
#  ('최', 2),
#  ('난', 2),
#  ('평', 2),
#  ('편', 2),
#  ('계', 2),
#  ('졋', 2),
#  ('s', 2),
#  ('9', 2),
#  ('본', 2),
#  ('추', 2),
#  ('x', 2),
#  ('뭔', 2),
#  ('ㅜ', 2),
#  ('법', 2),
#  ('켜', 2),
#  ('밤', 2),
#  ("'", 2),
#  ('젤', 2),
#  ('쏙', 2),
#  ('순', 2),
#  ('금', 2),
#  ('조', 2),
#  ('힐', 2),
#  ('단', 2),
#  ('백', 2),
#  ('임', 2),
#  ('맛', 2),
#  ('_', 2),
#  ('준', 2),
#  ('길', 2),
#  ('치', 2),
#  ('벌', 2),
#  ('찬', 2),
#  ('회', 2),
#  ('막', 1),
#  ('동', 1),
#  ('표', 1),
#  ('헤', 1),
#  ('탑', 1),
#  ('근', 1),
#  ('종', 1),
#  ('😄', 1),
#  ('쯤', 1),
#  ('S', 1),
#  ('셈', 1),
#  ('셔', 1),
#  ('입', 1),
#  ('헬', 1),
#  ('랄', 1),
#  ('겟', 1),
#  ('각', 1),
#  ('책', 1),
#  ('엇', 1),
#  ('택', 1),
#  ('4', 1),
#  ('넒', 1),
#  ('*', 1),
#  ('박', 1),
#  ('호', 1),
#  ('능', 1),
#  ('란', 1),
#  ('햐', 1),
#  ('ㄹ', 1),
#  ('샘', 1),
#  ('핑', 1),
#  ('흥', 1),
#  ('삼', 1),
#  ('우', 1),
#  ('피', 1),
#  ('료', 1),
#  ('딸', 1),
#  ('습', 1),
#  ('겨', 1),
#  ('렵', 1),
#  ('차', 1),
#  ('짤', 1),
#  ('졸', 1),
#  ('뭣', 1),
#  ('흉', 1),
#  ('괜', 1),
#  ('온', 1),
#  ('모', 1),
#  ('연', 1),
#  ('롭', 1),
#  ('겹', 1),
#  ('흠', 1),
#  ('창', 1),
#  ('군', 1),
#  ('썩', 1),
#  ('뇌', 1),
#  ('발', 1),
#  ('형', 1),
#  ('튕', 1),
#  ('척', 1),
#  ('병', 1),
#  ('둘', 1),
#  ('리', 1),
#  ('뷰', 1),
#  ('누', 1),
#  ('화', 1),
#  ('둥', 1),
#  ('욥', 1),
#  ('🙏', 1),
#  ('승', 1),
#  ('얗', 1),
#  ('반', 1),
#  ('핫', 1),
#  ('잠', 1),
#  ('옴', 1),
#  ('절', 1),
#  ('떡', 1),
#  ('빛', 1),
#  ('렉', 1),
#  ('뜻', 1),
#  ('경', 1),
#  ('쇼', 1),
#  ('겁', 1),
#  ('틈', 1),
#  ('겸', 1),
#  ('궁', 1),
#  ('빡', 1),
#  ('탓', 1),
#  ('떼', 1),
#  ('헉', 1),
#  ('효', 1),
#  ('및', 1),
#  ('팅', 1),
#  ('옷', 1),
#  ('며', 1),
#  ('작', 1),
#  ('월', 1),
#  ('귄', 1),
#  ('😉', 1),
#  ('엉', 1),
#  ('땜', 1),
#  ('랏', 1),
#  ('쿠', 1),
#  ('6', 1),
#  ('당', 1),
#  ('믄', 1),
#  ('밑', 1),
#  ('깅', 1),
#  ('합', 1),
#  ('I', 1),
#  ('염', 1)]

# %%
remove_one_word = [x for x in words if len(x)>1 or x=="굿" or x=="굳" or x=="짱" or x=="돈"]
len(remove_one_word)
# Out:
# 27959

# %%
from collections import Counter
frequent = Counter(remove_one_word).most_common()
frequent
# Out:
# [('하다', 2084),
#  ('간병인', 1067),
#  ('좋다', 965),
#  ('있다', 716),
#  ('간병', 447),
#  ('감사하다', 329),
#  ('되다', 312),
#  ('같다', 305),
#  ('너무', 300),
#  ('자다', 299),
#  ('보다', 260),
#  ('해주다', 253),
#  ('으로', 253),
#  ('편하다', 253),
#  ('..', 250),
#  ('케어', 241),
#  ('많다', 236),
#  ('없다', 209),
#  ('받다', 192),
#  ('에서', 190),
#  ('네이션', 186),
#  ('이다', 185),
#  ('되어다', 179),
#  ('선택', 178),
#  ('많이', 176),
#  ('하고', 163),
#  ('어플', 159),
#  ('이용', 159),
#  ('후기', 157),
#  ('정말', 152),
#  ('^^', 148),
#  ('처음', 141),
#  ('친절하다', 135),
#  ('환자', 132),
#  ('사용', 130),
#  ('!!', 126),
#  ('...', 125),
#  ('매칭', 116),
#  ('추천', 114),
#  ('만나다', 111),
#  ('알다', 110),
#  ('생각', 109),
#  ('오다', 107),
#  ('보고', 107),
#  ('않다', 103),
#  ('필요하다', 98),
#  ('지원', 95),
#  ('결제', 94),
#  ('병원', 91),
#  ('도움', 89),
#  ('쓰다', 88),
#  ('보호자', 87),
#  ('써다', 87),
#  ('덕분', 86),
#  ('만족스럽다', 85),
#  ('마음', 84),
#  ('일자리', 84),
#  ('해봤다', 83),
#  ('다른', 83),
#  ('찾다', 82),
#  ('서비스', 77),
#  ('해보다', 76),
#  ('여기', 75),
#  ('걱정', 74),
#  ('엄마', 74),
#  ('힘들다', 74),
#  ('만족하다', 72),
#  ('센터', 71),
#  ('ㅎㅎ', 71),
#  ('드리다', 70),
#  ('고객', 69),
#  ('들다', 69),
#  ('카드', 69),
#  ('어렵다', 68),
#  ('괜찮다', 66),
#  ('전화', 65),
#  ('구해', 65),
#  ('싶다', 64),
#  ('급하다', 64),
#  ('업체', 63),
#  ('경력', 63),
#  ('정보', 62),
#  ('에는', 62),
#  ('이라', 61),
#  ('사람', 61),
#  ('어떻다', 60),
#  ('모르다', 60),
#  ('!!!', 60),
#  ('안되다', 59),
#  ('여러', 59),
#  ('협회', 59),
#  ('공고', 57),
#  ('계속', 56),
#  ('직접', 56),
#  ('쉬다', 55),
#  ('시간', 54),
#  ('ㅠㅠ', 54),
#  ('그렇다', 53),
#  ('아니다', 52),
#  ('돼다', 52),
#  ('제일', 52),
#  ('~~', 51),
#  ('가족', 51),
#  ('다음', 50),
#  ('가다', 49),
#  ('까지', 48),
#  ('빠르다', 48),
#  ('이번', 47),
#  ('미리', 47),
#  ('편리하다', 47),
#  ('조금', 46),
#  ('여기다', 45),
#  ('분들', 45),
#  ('고맙다', 43),
#  ('상태', 43),
#  ('차다', 43),
#  ('이렇다', 43),
#  ('한번', 42),
#  ('가장', 42),
#  ('다운', 42),
#  ('때문', 41),
#  ('입원', 41),
#  ('일이', 40),
#  ('원하다', 40),
#  ('한테', 40),
#  ('바로', 40),
#  ('에도', 39),
#  ('그래도', 39),
#  ('진짜', 38),
#  ('고르다', 38),
#  ('비용', 38),
#  ('부담', 38),
#  ('연장', 38),
#  ('돌보다', 38),
#  ('쓸다', 38),
#  ('리뷰', 37),
#  ('꼼꼼하다', 37),
#  ('아버지', 36),
#  ('인데', 36),
#  ('불편하다', 36),
#  ('지방', 36),
#  ('주다', 35),
#  ('남기다', 35),
#  ('다행', 35),
#  ('일감', 35),
#  ('넘다', 34),
#  ('상황', 34),
#  ('수술', 34),
#  ('신청', 33),
#  ('상담', 33),
#  ('감사', 33),
#  ('올리다', 33),
#  ('이모', 33),
#  ('빨리', 32),
#  ('가입', 32),
#  ('유용하다', 32),
#  ('전화하다', 32),
#  ('확실하다', 32),
#  ('만들다', 32),
#  ('라서', 32),
#  ('마다', 31),
#  ('에게', 31),
#  ('믿다', 31),
#  ('ㅎㅎㅎ', 31),
#  ('이랑', 31),
#  ('시작', 30),
#  ('하나', 30),
#  ('부분', 30),
#  ('프로필', 30),
#  ('그냥', 29),
#  ('부터', 29),
#  ('이나', 29),
#  ('맞다', 29),
#  ('깔다', 29),
#  ('다시', 29),
#  ('어머니', 29),
#  ('돈', 28),
#  ('연락', 28),
#  ('열심히', 28),
#  ('코로나', 27),
#  ('자주', 27),
#  ('크다', 27),
#  ('~^^', 27),
#  ('니까', 27),
#  ('늘다', 26),
#  ('최고', 26),
#  ('광고', 26),
#  ('생기다', 26),
#  ('야하다', 26),
#  ('만족', 25),
#  ('이렇게', 25),
#  ('없이', 25),
#  ('등록', 24),
#  ('확인', 24),
#  ('소개', 24),
#  ('이제', 24),
#  ('하루', 23),
#  ('이네', 23),
#  ('아주', 23),
#  ('가능하다', 23),
#  ('검색', 23),
#  ('안심', 23),
#  ('오신', 23),
#  ('통해', 23),
#  ('처럼', 23),
#  ('들어오다', 23),
#  ('보내다', 22),
#  ('근데', 22),
#  ('설명', 22),
#  ('정도', 22),
#  ('대한', 22),
#  ('현금', 22),
#  ('추가', 22),
#  ('깔끔하다', 22),
#  ('고민', 22),
#  ('수수료', 22),
#  ('굿', 22),
#  ('아직', 22),
#  ('훨씬', 21),
#  ('별로', 21),
#  ('항상', 21),
#  ('불안하다', 21),
#  ('신경', 21),
#  ('친구', 21),
#  ('기다리다', 21),
#  ('이에요', 20),
#  ('물어보다', 20),
#  ('쉽다', 20),
#  ('지인', 20),
#  ('구한', 20),
#  ('느끼다', 20),
#  ('퇴원', 20),
#  ('짧다', 20),
#  ('가격', 20),
#  ('챙기다', 20),
#  ('같이', 20),
#  ('문제', 19),
#  ('찾기', 19),
#  ('주변', 19),
#  ('나이', 19),
#  ('아빠', 19),
#  ('....', 19),
#  ('신기하다', 19),
#  ('취소', 19),
#  ('덜다', 19),
#  ('다르다', 19),
#  ('뜨다', 18),
#  ('연결', 18),
#  ('바꾸다', 18),
#  ('일도', 18),
#  ('매번', 18),
#  ('믿음', 18),
#  ('비싸다', 18),
#  ('갑자기', 18),
#  ('잇다', 18),
#  ('이라서', 18),
#  ('사실', 18),
#  ('남다', 18),
#  ('시간제', 18),
#  ('요즘', 18),
#  ('막막하다', 18),
#  ('시스템', 18),
#  ('느껴지다', 17),
#  ('요청', 17),
#  ('알아보다', 17),
#  ('도와주다', 17),
#  ('이유', 17),
#  ('할부', 17),
#  ('이벤트', 17),
#  ('기대', 17),
#  ('비교', 16),
#  ('저희', 16),
#  ('답답하다', 16),
#  ('지금', 16),
#  ('좋아하다', 16),
#  ('더욱', 16),
#  ('메이트', 16),
#  ('고생', 16),
#  ('장점', 16),
#  ('이런', 15),
#  ('에서는', 15),
#  ('그래서', 15),
#  ('문의', 15),
#  ('신뢰', 15),
#  ('적다', 15),
#  ('기능', 15),
#  (':)', 15),
#  ('비도', 15),
#  ('배우다', 15),
#  ('오래', 15),
#  ('께서', 15),
#  ('완전', 15),
#  ('오히려', 15),
#  ('굳다', 15),
#  ('걸리다', 15),
#  ('보험', 15),
#  ('혼자', 15),
#  ('보이다', 15),
#  ('참고', 15),
#  ('종종', 15),
#  ('여사', 15),
#  ('매일', 15),
#  ('라고', 14),
#  ('나오다', 14),
#  ('자체', 14),
#  ('높다', 14),
#  ('단기', 14),
#  ('소통', 14),
#  ('입장', 14),
#  ('놓다', 14),
#  ('아쉽다', 14),
#  ('내다', 14),
#  ('유튜브', 14),
#  ('으로도', 14),
#  ('커뮤니티', 14),
#  ('회사', 14),
#  ('힘드다', 14),
#  ('아프다', 14),
#  ('자격증', 14),
#  ('어머님', 14),
#  ('통장', 14),
#  ('금액', 13),
#  ('건지다', 13),
#  ('원래', 13),
#  ('관리', 13),
#  ('핸드폰', 13),
#  ('자세하다', 13),
#  ('비다', 13),
#  ('진행', 13),
#  ('전문', 13),
#  ('해주시', 13),
#  ('신분', 13),
#  ('에서도', 13),
#  ('모습', 13),
#  ('한국인', 13),
#  ('익숙해지다', 13),
#  ('로그인', 12),
#  ('해결', 12),
#  ('탈퇴', 12),
#  ('기다', 12),
#  ('세심', 12),
#  ('결국', 12),
#  ('결과', 12),
#  ('ㅠㅠㅠㅠ', 12),
#  ('복불복', 12),
#  ('늘어나다', 12),
#  ('엄청', 12),
#  ('서다', 12),
#  ('합리', 12),
#  ('놓이다', 12),
#  ('따로', 12),
#  ('말다', 12),
#  ('남편', 12),
#  ('쌓이다', 12),
#  ('올라오다', 12),
#  ('뿌듯하다', 12),
#  ('보람', 12),
#  ('입금', 12),
#  ('오류', 11),
#  ('바라다', 11),
#  ('회원', 11),
#  ('들어가다', 11),
#  ('부르다', 11),
#  ('간단하다', 11),
#  ('역시', 11),
#  ('따뜻하다', 11),
#  ('좋아지다', 11),
#  ('아버님', 11),
#  ('나가다', 11),
#  ('방법', 11),
#  ('저렴하다', 11),
#  ('모두', 11),
#  ('간편하다', 11),
#  ('기간', 11),
#  ('헷갈리다', 11),
#  ('카페', 11),
#  ('한다는', 11),
#  ('검사', 11),
#  ('젊다', 11),
#  ('스럽다', 11),
#  ('책임감', 11),
#  ('스케줄', 11),
#  ('ㅋㅋ', 11),
#  ('서울', 11),
#  ('인지', 11),
#  ('굿굿', 11),
#  ('카카오', 10),
#  ('권한', 10),
#  ('지다', 10),
#  ('듣다', 10),
#  ('예전', 10),
#  ('덜하다', 10),
#  ('편안하다', 10),
#  ('사진', 10),
#  ('살다', 10),
#  ('고용', 10),
#  ('다양하다', 10),
#  ('이고', 10),
#  ('어려움', 10),
#  ('동안', 10),
#  ('굉장하다', 10),
#  ('필요', 10),
#  ('시키다', 10),
#  ('일정', 10),
#  ('다행하다', 10),
#  ('귀찮다', 10),
#  ('병사', 10),
#  ('빼다', 10),
#  ('두번째', 10),
#  ('대해', 10),
#  ('남자', 10),
#  ('써주다', 10),
#  ('선생님', 10),
#  ('비슷하다', 10),
#  ('많아지다', 10),
#  ('??', 10),
#  ('지역', 10),
#  ('네트워크', 9),
#  ('설정', 9),
#  ('내용', 9),
#  ('누르다', 9),
#  ('플랫폼', 9),
#  ('분도', 9),
#  ('분과', 9),
#  ('스트레스', 9),
#  ('불다', 9),
#  ('궁금하다', 9),
#  ('찾아보다', 9),
#  ('지만', 9),
#  ('하지만', 9),
#  ('몇번', 9),
#  ('자기', 9),
#  ('신청서', 9),
#  ('작성', 9),
#  ('계시다', 9),
#  ('맡기다', 9),
#  ('능숙하다', 9),
#  ('달라', 9),
#  ('맞추다', 9),
#  ('금방', 9),
#  ('요금', 9),
#  ('모로', 9),
#  ('자리', 9),
#  ('요구', 9),
#  ('작년', 9),
#  ('어리다', 9),
#  ('쓰기', 9),
#  ('제안', 9),
#  ('나다', 9),
#  ('관련', 9),
#  ('적응', 9),
#  ('기분', 9),
#  ('이상', 9),
#  ('삭제', 8),
#  ('날짜', 8),
#  ('하니', 8),
#  ('아깝다', 8),
#  ('전혀', 8),
#  ('만날', 8),
#  ('말씀', 8),
#  ('세상', 8),
#  ('나서다', 8),
#  ('버튼', 8),
#  ('정신', 8),
#  ('신입', 8),
#  ('그런데', 8),
#  ('일단', 8),
#  ('물론', 8),
#  ('조건', 8),
#  ('성격', 8),
#  ('서로', 8),
#  ('유명하다', 8),
#  ('얻다', 8),
#  ('감동', 8),
#  ('직원', 8),
#  ('매우', 8),
#  ('업데이트', 8),
#  ('나쁘다', 8),
#  ('해지', 8),
#  ('사이', 8),
#  ('이틀', 8),
#  ('인거', 8),
#  ('당황', 8),
#  ('맡다', 8),
#  ('한시름', 8),
#  ('카톡', 8),
#  ('실제', 8),
#  ('평가', 8),
#  ('안내', 8),
#  ('나름', 8),
#  ('당일', 8),
#  ('진심', 8),
#  ('이라고', 8),
#  ('무난', 8),
#  ('재밌다', 8),
#  ('따다', 8),
#  ('먹다', 8),
#  ('전국', 8),
#  ('먼저', 8),
#  ('듭니', 8),
#  ('쌓다', 8),
#  ('부모님', 8),
#  ('요양보호사', 8),
#  ('끄다', 7),
#  ('해도', 7),
#  ('아무', 7),
#  ('그리고', 7),
#  ('정기', 7),
#  ('오시', 7),
#  ('ㅠㅠㅠㅠㅠ', 7),
#  ('괜히', 7),
#  ('입력', 7),
#  ('길다', 7),
#  ('그만큼', 7),
#  ('여서', 7),
#  ('필요없다', 7),
#  ('건강', 7),
#  ('아무래도', 7),
#  ('수월하다', 7),
#  ('여기저기', 7),
#  ('얼굴', 7),
#  ('보다는', 7),
#  ('느낌', 7),
#  ('발전', 7),
#  ('약간', 7),
#  ('꾸준하다', 7),
#  ('경험', 7),
#  ('인터넷', 7),
#  ('제시', 7),
#  ('시대', 7),
#  ('입찰', 7),
#  ('라면', 7),
#  ('그나마', 7),
#  ('가끔', 7),
#  ('얼마', 7),
#  ('솔직하다', 7),
#  ('일주일', 7),
#  ('후회', 7),
#  ('영상', 7),
#  ('기도', 7),
#  ('공부', 7),
#  ('돌리다', 7),
#  ('그런', 7),
#  ('부탁드리다', 7),
#  ('ㅎㅎㅎㅎ', 7),
#  ('들어서다', 7),
#  ('지치다', 7),
#  ('막상', 7),
#  ('개선', 7),
#  ('반신반의', 7),
#  ('프로', 7),
#  ('눈치', 7),
#  ('낫다', 7),
#  ('???', 7),
#  ('지는', 7),
#  ('웃다', 7),
#  ('바로바로', 7),
#  ('짜다', 7),
#  ('하나요', 7),
#  ('교육', 7),
#  ('본인', 7),
#  ('자꾸', 7),
#  ('혹시', 7),
#  ('아내', 7),
#  ('추하다', 7),
#  ('이체', 7),
#  ('설치', 6),
#  ('그렇게', 6),
#  ('정이', 6),
#  ('확률', 6),
#  ('로만', 6),
#  ('이어서', 6),
#  ('는걸', 6),
#  ('얼마나', 6),
#  ('보살피다', 6),
#  ('말고', 6),
#  ('다만', 6),
#  ('만족도', 6),
#  ('적극', 6),
#  ('장기', 6),
#  ('과정', 6),
#  ('콘텐츠', 6),
#  ('생활', 6),
#  ('구인', 6),
#  ('중간', 6),
#  ('가지', 6),
#  ('블로그', 6),
#  ('화이팅', 6),
#  ('비우다', 6),
#  ('대비', 6),
#  ('ㅋㅋㅋ', 6),
#  ('~~~', 6),
#  ('라디오', 6),
#  ('~!', 6),
#  ('며칠', 6),
#  ('이야기', 6),
#  ('함께', 6),
#  ('당연하다', 6),
#  ('편이', 6),
#  ('응대', 6),
#  ('갑작스럽다', 6),
#  ('개발', 6),
#  ('두다', 6),
#  ('이름', 6),
#  ('나중', 6),
#  ('상세', 6),
#  ('어찌', 6),
#  ('성실하다', 6),
#  ('여러가지', 6),
#  ('티비', 6),
#  ('으로는', 6),
#  ('다니다', 6),
#  ('번째', 6),
#  ('책임', 6),
#  ('에게도', 6),
#  ('근처', 6),
#  ('위해', 6),
#  ('알바', 6),
#  ('병실', 6),
#  ('약관', 6),
#  ('갈다', 6),
#  ('벌다', 6),
#  ('적응하다', 6),
#  ('라는', 5),
#  ('일당', 5),
#  ('제대로', 5),
#  ('거의', 5),
#  ('의사소통', 5),
#  ('안해', 5),
#  ('어디', 5),
#  ('굳이', 5),
#  ('활용', 5),
#  ('에만', 5),
#  ('급격하다', 5),
#  ('기억', 5),
#  ('예요', 5),
#  (',,', 5),
#  ('3일', 5),
#  ('직업', 5),
#  ('언제', 5),
#  ('이건', 5),
#  ('중국인', 5),
#  ('한국', 5),
#  ('중요하다', 5),
#  ('복잡하다', 5),
#  ('에요', 5),
#  ('방식', 5),
#  ('그게', 5),
#  ('어찌나', 5),
#  ('보통', 5),
#  ('스스로', 5),
#  ('중증', 5),
#  ('얘기', 5),
#  ('배상', 5),
#  ('번창', 5),
#  ('다해', 5),
#  ('만에', 5),
#  ('겠다', 5),
#  ('특히', 5),
#  ('사라지다', 5),
#  ('지식', 5),
#  ('안좋다', 5),
#  ('새롭다', 5),
#  ('치매', 5),
#  ('고해', 5),
#  ('도저히', 5),
#  ('만난', 5),
#  ('대로', 5),
#  ('이제야', 5),
#  ('되게', 5),
#  ('제라', 5),
#  ('부담스럽다', 5),
#  ('!!!!', 5),
#  ('대부분', 5),
#  ('이라는', 5),
#  ('판단', 5),
#  ('초보', 5),
#  ('안구', 5),
#  ('기본', 5),
#  ('문화', 5),
#  ('ㅡㅡ', 5),
#  ('낮다', 5),
#  ('짱', 5),
#  ('서도', 5),
#  ('뭔가', 5),
#  ('섬망', 5),
#  ('노력', 5),
#  ('뿐이다', 5),
#  ('보기', 5),
#  ('뇌출혈', 5),
#  ('어쩔', 5),
#  ('읍니', 5),
#  ('해드리다', 5),
#  ('느리다', 5),
#  ('죄송하다', 5),
#  ('문자', 5),
#  ('성공하다', 5),
#  ('인정', 5),
#  ('좀더', 5),
#  ('아이', 5),
#  ('용하다', 5),
#  ('자유롭다', 5),
#  ('부업', 5),
#  ('대우', 5),
#  ('선호', 5),
#  ('날때', 5),
#  ('재미', 5),
#  ('정산', 5),
#  ('유니폼', 5),
#  ('주말', 4),
#  ('가요', 4),
#  ('수정', 4),
#  ('조율', 4),
#  ('배려', 4),
#  ('우연히', 4),
#  ('차승원', 4),
#  ('끝나다', 4),
#  ('부탁', 4),
#  ('은근', 4),
#  ('예정', 4),
#  ('밖에', 4),
#  ('마침', 4),
#  ('마치다', 4),
#  ('던지다', 4),
#  ('면회', 4),
#  ('표정', 4),
#  ('심하다', 4),
#  ('기회', 4),
#  ('으로만', 4),
#  ('없어지다', 4),
#  ('넓다', 4),
#  ('중개', 4),
#  ('기대하다', 4),
#  ('바쁘다', 4),
#  ('회복하다', 4),
#  ('외국인', 4),
#  ('이해', 4),
#  ('.!!', 4),
#  ('일일이', 4),
#  ('고려', 4),
#  ('한가지', 4),
#  ('.....', 4),
#  ('겪다', 4),
#  ('그거', 4),
#  ('할머니', 4),
#  ('워낙', 4),
#  ('까다롭다', 4),
#  ('치다', 4),
#  ('편찮다', 4),
#  ('스마트폰', 4),
#  ('복사', 4),
#  ('서툴다', 4),
#  ('물어', 4),
#  ('줄다', 4),
#  ('인구', 4),
#  ('정찰', 4),
#  ('무사하다', 4),
#  ('돌아가다', 4),
#  ('어느', 4),
#  ('인상', 4),
#  ('쓰러지다', 4),
#  ('어제', 4),
#  ('이르다', 4),
#  ('한참', 4),
#  ('무엇', 4),
#  ('일방', 4),
#  ('힘내다', 4),
#  ('그중', 4),
#  ('부족하다', 4),
#  ('요새', 4),
#  ('겨우', 4),
#  ('ㅜㅜ', 4),
#  ('무조건', 4),
#  ('보지', 4),
#  ('웃돈', 4),
#  ('인연', 4),
#  ('이기다', 4),
#  ('싸우다', 4),
#  ('대충', 4),
#  ('전부', 4),
#  ('예약', 4),
#  ('개다', 4),
#  ('생기', 4),
#  ('수고', 4),
#  ('우선', 4),
#  ('쓰이다', 4),
#  ('어색하다', 4),
#  ('오랜', 4),
#  ('벌써', 4),
#  ('모든', 4),
#  ('24시간', 4),
#  ('전문가', 4),
#  ('점점', 4),
#  ('허용', 4),
#  ('화면', 4),
#  ('떼다', 4),
#  ('일만', 4),
#  ('말동무', 4),
#  ('종일', 4),
#  ('싫다', 4),
#  ('위약금', 4),
#  ('이라도', 4),
#  ('똑같다', 4),
#  ('수가', 4),
#  ('서울대', 4),
#  ('시도', 4),
#  ('여유', 4),
#  ('그때', 4),
#  ('.^^', 4),
#  ('드네', 4),
#  ('시간대', 4),
#  ('따르다', 4),
#  ('보이', 4),
#  ('위로', 4),
#  ('기쁘다', 4),
#  ('군데', 4),
#  ('..^^', 4),
#  ('나은', 4),
#  ('주심', 4),
#  ('프리랜서', 4),
#  ('예민하다', 4),
#  ('다가', 4),
#  ('우리', 4),
#  ('칭찬', 4),
#  ('뭐라다', 4),
#  ('간호사', 4),
#  ('나누다', 4),
#  ('~!!', 4),
#  ('비추다', 4),
#  ('보여주다', 4),
#  ('용돈', 4),
#  ('보험료', 4),
#  ('와이파이', 3),
#  ('열리다', 3),
#  ('아예', 3),
#  ('접속', 3),
#  ('9일', 3),
#  ('10일', 3),
#  ('어쩌', 3),
#  ('로는', 3),
#  ('무슨', 3),
#  ('변하다', 3),
#  ('번거롭다', 3),
#  ('크게', 3),
#  ('정성껏', 3),
#  ('햇습니', 3),
#  ('봉사', 3),
#  ('뽑다', 3),
#  ('점도', 3),
#  ('동영상', 3),
#  ('액세스', 3),
#  ('권한부여', 3),
#  ('들이다', 3),
#  ('개인', 3),
#  ('100%', 3),
#  ('연세', 3),
#  ('뉴스', 3),
#  ('넘어오다', 3),
#  ('빨르다', 3),
#  ('이기', 3),
#  ('대신', 3),
#  ('정해진', 3),
#  ('척척', 3),
#  ('대화', 3),
#  ('전달', 3),
#  ('출장', 3),
#  ('따름', 3),
#  ('목소리', 3),
#  ('말고는', 3),
#  ('성장하다', 3),
#  ('이분', 3),
#  ('네이버', 3),
#  ('운영', 3),
#  ('매달', 3),
#  ('애용', 3),
#  ('임신', 3),
#  ('지도', 3),
#  ('충격', 3),
#  ('CS', 3),
#  ('완료', 3),
#  ('버스', 3),
#  ('피곤하다', 3),
#  ('치고', 3),
#  ('누구', 3),
#  ('적당하다', 3),
#  ('기준', 3),
#  ('낭비하다', 3),
#  ('절차', 3),
#  ('최선', 3),
#  ('오기', 3),
#  ('어르신', 3),
#  ('이전', 3),
#  ('울다', 3),
#  ('자세', 3),
#  ('고마', 3),
#  ('사항', 3),
#  ('타지', 3),
#  ('채팅', 3),
#  ('말씀드리다', 3),
#  ('기선', 3),
#  ('슬프다', 3),
#  ('조선족', 3),
#  ('정착', 3),
#  ('다섯', 3),
#  ('생소하다', 3),
#  ('주위', 3),
#  ('이란', 3),
#  ('인식', 3),
#  ('덥다', 3),
#  ('차이', 3),
#  ('나요', 3),
#  ('보상', 3),
#  ('단기간', 3),
#  ('대응', 3),
#  ('엄청나다', 3),
#  ('노하우', 3),
#  ('사용설명서', 3),
#  ('ㅠㅠㅠ', 3),
#  ('사용자', 3),
#  ('의사', 3),
#  ('스럽게', 3),
#  ('수준', 3),
#  ('시기', 3),
#  ('능력', 3),
#  ('컨디션', 3),
#  ('할아버지', 3),
#  ('포기', 3),
#  ('예상', 3),
#  ('끼다', 3),
#  ('재활', 3),
#  ('사분', 3),
#  ('지키다', 3),
#  ('난감하다', 3),
#  ('살펴보다', 3),
#  ('스타일', 3),
#  ('심심하다', 3),
#  ('한텐', 3),
#  ('돌다', 3),
#  ('출근', 3),
#  ('잘알다', 3),
#  ('멀다', 3),
#  ('편입', 3),
#  ('버리다', 3),
#  ('어플리케이션', 3),
#  ('조아', 3),
#  ('연결하다', 3),
#  ('의지', 3),
#  ('동료', 3),
#  ('유익하다', 3),
#  ('잠시', 3),
#  ('상담사', 3),
#  ('지난번', 3),
#  ('욕창', 3),
#  ('처리', 3),
#  ('구경', 3),
#  ('교체', 3),
#  ('불가능하다', 3),
#  ('이니', 3),
#  ('내색', 3),
#  ('변경', 3),
#  ('~~^^', 3),
#  ('먹통', 3),
#  ('실패하다', 3),
#  ('깊다', 3),
#  ('나아지다', 3),
#  ('남아', 3),
#  ('탁월하다', 3),
#  ('허리', 3),
#  ('~~~~', 3),
#  ('(^^)', 3),
#  ('아무리', 3),
#  ('살짝', 3),
#  ('장기간', 3),
#  ('놀라다', 3),
#  ('한데', 3),
#  ('수도권', 3),
#  ('내내', 3),
#  ('저만', 3),
#  ('1일', 3),
#  ('건강하다', 3),
#  ('아이폰', 3),
#  ('가야', 3),
#  ('이신', 3),
#  ('파악', 3),
#  ('여태', 3),
#  ('10시', 3),
#  ('아침', 3),
#  ('오늘', 3),
#  ('바람', 3),
#  ('체적', 3),
#  ('홍보', 3),
#  ('어디서', 3),
#  ('나니', 3),
#  ('진정', 3),
#  ('막히다', 3),
#  ('정해지다', 3),
#  ('화장실', 3),
#  ('중국', 3),
#  ('날다', 3),
#  ('이지만', 3),
#  ...]

# %%
def tokenize_reviews_list(reviews):
    tokens = okt.morphs(reviews, stem=True)
    return ' '.join(tokens)

# %%
df_care_only['tokenized_review'] = df_care_only['spaced_review'].apply(tokenize_reviews_list)
df_care_only[:5]
# Out:
# C:\Users\moony\AppData\Local\Temp\ipykernel_2928\1505949571.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_care_only['tokenized_review'] = df_care_only['spaced_review'].apply(tokenize_reviews_list)
#                            title           reviewer   review_date  \
# 0  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기     n Butter Bread   2023년 8월 5일
# 1  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기            XXX XXX  2023년 10월 3일
# 2  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                신미경  2023년 9월 27일
# 3  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                백승희  2023년 10월 3일
# 4  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기  Jeju life Jaymi's  2023년 9월 28일
#
#                                              content  rate_int  \
# 0  네트워크오류라고 나와서 와이파이 끄고 하면 로그인 안되고 일시적인 오류라고 계속 뜹...         1
# 1  카카오로 시작하기로 가입햇는데 로그인후 카카오로 로그인이 안됩니다 계속 튕기고 삭제...         1
# 2  앱열기가 안되네여.. 삭제후 재설치..권한도 설정들어가서 직접했는데도 앱자체가 안열...         1
# 3  카카오로 시작하기가 안됩니다. 크롬에서 카카오로 가입 후 건뱡신청 했는데 어플에서는...         4
# 4  앱 접속할때마다 네트워크가 없다고 떠요. 어떻게 사용하라는건가요? 그리고 간병금액 ...         2
#
#                                        spaced_review  \
# 0  네트워크 오류라고 나와서 와이파이 끄고 하면 로그인 안 되고 일시적인 오류라고 계속...
# 1  카카오로 시작하기로 가입 햇는데 로그인 후 카카오로 로그인이 안 됩니다 계속 튕기고...
# 2  앱 열기가 안 되네 여.. 삭제 후 재 설치..권한도 설정 들어가서 직접 했는데도 ...
# 3  카카오로 시작하기가 안 됩니다. 크롬에서 카카오로 가입 후 건 뱡 신청 했는데 어플...
# 4  앱 접속할 때마다 네트워크가 없다고 떠요. 어떻게 사용하라는 건가요? 그리고 간병 ...
#
#                                     tokenized_review
# 0  네트워크 오류 라고 나오다 와이파이 끄다 하다 로그인 안 되다 일시 적 인 오류 라...
# 1  카카오 로 시작 하다 가입 햇 늘다 로그인 후 카카오 로 로그인 이 안 되다 계속 ...
# 2  앱 열기 가 안 되다 여 .. 삭제 후 재 설치 .. 권한 도 설정 들어가다 직접 ...
# 3  카카오 로 시작 하다 안 되다 . 크롬 에서 카카오 로 가입 후 건 뱡 신청 하다 ...
# 4  앱 접속 하다 때 마다 네트워크 가 없다 뜨다 . 어떻다 사용 하 라는 건가 요 ?...

# %%
df_care_only['replaced_review'] = df_care_only['tokenized_review'].apply(replace_word)
df_care_only[:5]
# Out:
# C:\Users\moony\AppData\Local\Temp\ipykernel_2928\817790128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_care_only['replaced_review'] = df_care_only['tokenized_review'].apply(replace_word)
#                            title           reviewer   review_date  \
# 0  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기     n Butter Bread   2023년 8월 5일
# 1  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기            XXX XXX  2023년 10월 3일
# 2  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                신미경  2023년 9월 27일
# 3  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                백승희  2023년 10월 3일
# 4  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기  Jeju life Jaymi's  2023년 9월 28일
#
#                                              content  rate_int  \
# 0  네트워크오류라고 나와서 와이파이 끄고 하면 로그인 안되고 일시적인 오류라고 계속 뜹...         1
# 1  카카오로 시작하기로 가입햇는데 로그인후 카카오로 로그인이 안됩니다 계속 튕기고 삭제...         1
# 2  앱열기가 안되네여.. 삭제후 재설치..권한도 설정들어가서 직접했는데도 앱자체가 안열...         1
# 3  카카오로 시작하기가 안됩니다. 크롬에서 카카오로 가입 후 건뱡신청 했는데 어플에서는...         4
# 4  앱 접속할때마다 네트워크가 없다고 떠요. 어떻게 사용하라는건가요? 그리고 간병금액 ...         2
#
#                                        spaced_review  \
# 0  네트워크 오류라고 나와서 와이파이 끄고 하면 로그인 안 되고 일시적인 오류라고 계속...
# 1  카카오로 시작하기로 가입 햇는데 로그인 후 카카오로 로그인이 안 됩니다 계속 튕기고...
# 2  앱 열기가 안 되네 여.. 삭제 후 재 설치..권한도 설정 들어가서 직접 했는데도 ...
# 3  카카오로 시작하기가 안 됩니다. 크롬에서 카카오로 가입 후 건 뱡 신청 했는데 어플...
# 4  앱 접속할 때마다 네트워크가 없다고 떠요. 어떻게 사용하라는 건가요? 그리고 간병 ...
#
#                                     tokenized_review  \
# 0  네트워크 오류 라고 나오다 와이파이 끄다 하다 로그인 안 되다 일시 적 인 오류 라...
# 1  카카오 로 시작 하다 가입 햇 늘다 로그인 후 카카오 로 로그인 이 안 되다 계속 ...
# 2  앱 열기 가 안 되다 여 .. 삭제 후 재 설치 .. 권한 도 설정 들어가다 직접 ...
# 3  카카오 로 시작 하다 안 되다 . 크롬 에서 카카오 로 가입 후 건 뱡 신청 하다 ...
# 4  앱 접속 하다 때 마다 네트워크 가 없다 뜨다 . 어떻다 사용 하 라는 건가 요 ?...
#
#                                      replaced_review
# 0  네트워크 오류 라고 나오다 와이파이 끄다 하다 로그인 안 되다 일시 적 인 오류 라...
# 1  카카오톡 로 시작 하다 회원가입 햇 늘다 로그인 후 카카오톡 로 로그인 이 안 되다...
# 2  애플리케이션 열기 가 안 되다 여 .. 삭제 후 재 설치 .. 권한 도 설정 들어가...
# 3  카카오톡 로 시작 하다 안 되다 . 크롬 에서 카카오톡 로 회원가입 후 건 뱡 신청...
# 4  애플리케이션 접속 하다 때 마다 네트워크 가 없다 뜨다 . 어떻다 사용 하 라는 건...

# %%
from konlpy.tag import Okt
okt = Okt()

with open('../stopwords.txt', 'r', encoding = 'utf-8') as f:
    list_file = f.readlines()
stopwords = list_file[0].split(",")


# 토크나이징 함수 정의(한자 이상 적용. 불용어 삭제)
def stopword(raw, pos=["Noun",'Adjective',"Alpha","Verb","Number"], stopword=stopwords):
    result_list = list()
    # for word in replaced_review :
    for word, tag in okt.pos(raw, norm=True, stem=True) :
        if tag in pos and word not in stopword:
            result_list.append(word)
    # 일부 경우(토큰 갯수 제한)
    # if len(result_list) <= 3 or len(result_list) < 12 :
    #   result_list
    return ' '.join(result_list) # return str

# %%
df_care_only['stopword_review'] = df_care_only['replaced_review'].apply(stopword)
df_care_only[:5]
# Out:
# C:\Users\moony\AppData\Local\Temp\ipykernel_2928\1728874227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_care_only['stopword_review'] = df_care_only['replaced_review'].apply(stopword)
#                            title           reviewer   review_date  \
# 0  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기     n Butter Bread   2023년 8월 5일
# 1  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기            XXX XXX  2023년 10월 3일
# 2  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                신미경  2023년 9월 27일
# 3  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                백승희  2023년 10월 3일
# 4  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기  Jeju life Jaymi's  2023년 9월 28일
#
#                                              content  rate_int  \
# 0  네트워크오류라고 나와서 와이파이 끄고 하면 로그인 안되고 일시적인 오류라고 계속 뜹...         1
# 1  카카오로 시작하기로 가입햇는데 로그인후 카카오로 로그인이 안됩니다 계속 튕기고 삭제...         1
# 2  앱열기가 안되네여.. 삭제후 재설치..권한도 설정들어가서 직접했는데도 앱자체가 안열...         1
# 3  카카오로 시작하기가 안됩니다. 크롬에서 카카오로 가입 후 건뱡신청 했는데 어플에서는...         4
# 4  앱 접속할때마다 네트워크가 없다고 떠요. 어떻게 사용하라는건가요? 그리고 간병금액 ...         2
#
#                                        spaced_review  \
# 0  네트워크 오류라고 나와서 와이파이 끄고 하면 로그인 안 되고 일시적인 오류라고 계속...
# 1  카카오로 시작하기로 가입 햇는데 로그인 후 카카오로 로그인이 안 됩니다 계속 튕기고...
# 2  앱 열기가 안 되네 여.. 삭제 후 재 설치..권한도 설정 들어가서 직접 했는데도 ...
# 3  카카오로 시작하기가 안 됩니다. 크롬에서 카카오로 가입 후 건 뱡 신청 했는데 어플...
# 4  앱 접속할 때마다 네트워크가 없다고 떠요. 어떻게 사용하라는 건가요? 그리고 간병 ...
#
#                                     tokenized_review  \
# 0  네트워크 오류 라고 나오다 와이파이 끄다 하다 로그인 안 되다 일시 적 인 오류 라...
# 1  카카오 로 시작 하다 가입 햇 늘다 로그인 후 카카오 로 로그인 이 안 되다 계속 ...
# 2  앱 열기 가 안 되다 여 .. 삭제 후 재 설치 .. 권한 도 설정 들어가다 직접 ...
# 3  카카오 로 시작 하다 안 되다 . 크롬 에서 카카오 로 가입 후 건 뱡 신청 하다 ...
# 4  앱 접속 하다 때 마다 네트워크 가 없다 뜨다 . 어떻다 사용 하 라는 건가 요 ?...
#
#                                      replaced_review  \
# 0  네트워크 오류 라고 나오다 와이파이 끄다 하다 로그인 안 되다 일시 적 인 오류 라...
# 1  카카오톡 로 시작 하다 회원가입 햇 늘다 로그인 후 카카오톡 로 로그인 이 안 되다...
# 2  애플리케이션 열기 가 안 되다 여 .. 삭제 후 재 설치 .. 권한 도 설정 들어가...
# 3  카카오톡 로 시작 하다 안 되다 . 크롬 에서 카카오톡 로 회원가입 후 건 뱡 신청...
# 4  애플리케이션 접속 하다 때 마다 네트워크 가 없다 뜨다 . 어떻다 사용 하 라는 건...
#
#                                      stopword_review one_word_removed
# 0  네트워크 오류 와이파이 로그인 안 일시 적 인 오류 뜨다 간병인 결정 결제 주말 이...
# 1  카카오 톡 시작 회원 가입 햇 늘다 로그인 후 카카오 톡 로그인 안 튕기 고 삭제 ...
# 2  애플리케이션 열기 안 삭제 후 재 설치 권한 도 설정 들어가다 직접 애플리케이션 안 리다
# 3  카카오 톡 시작 안 크롬 카카오 톡 회원 가입 후 건 뱡 신청 어플 카카오 톡 시작...
# 4  애플리케이션 접속 네트워크 뜨다 사용 건가 간병 금액 상한선 건 하루 당 30만원 ...

# %%
def remove_one_word(stopword_review):
    word_list = []
    for x in stopword_review:
        if len(x)>1 or (x in ["굿", "굳", "짱", "돈", "값"]):
            word_list.append(x)
    return ' '.join(word_list)

df_care_only['one_word_removed'] = df_care_only['stopword_review'].apply(remove_one_word)
df_care_only[:5]
# Out:
# C:\Users\moony\AppData\Local\Temp\ipykernel_2928\2342872519.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_care_only['one_word_removed'] = df_care_only['stopword_review'].apply(remove_one_word)
#                            title           reviewer   review_date  \
# 0  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기     n Butter Bread   2023년 8월 5일
# 1  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기            XXX XXX  2023년 10월 3일
# 2  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                신미경  2023년 9월 27일
# 3  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기                백승희  2023년 10월 3일
# 4  케어네이션 - 간병인, 병원 동행인, 요양보호사 찾기  Jeju life Jaymi's  2023년 9월 28일
#
#                                              content  rate_int  \
# 0  네트워크오류라고 나와서 와이파이 끄고 하면 로그인 안되고 일시적인 오류라고 계속 뜹...         1
# 1  카카오로 시작하기로 가입햇는데 로그인후 카카오로 로그인이 안됩니다 계속 튕기고 삭제...         1
# 2  앱열기가 안되네여.. 삭제후 재설치..권한도 설정들어가서 직접했는데도 앱자체가 안열...         1
# 3  카카오로 시작하기가 안됩니다. 크롬에서 카카오로 가입 후 건뱡신청 했는데 어플에서는...         4
# 4  앱 접속할때마다 네트워크가 없다고 떠요. 어떻게 사용하라는건가요? 그리고 간병금액 ...         2
#
#                                        spaced_review  \
# 0  네트워크 오류라고 나와서 와이파이 끄고 하면 로그인 안 되고 일시적인 오류라고 계속...
# 1  카카오로 시작하기로 가입 햇는데 로그인 후 카카오로 로그인이 안 됩니다 계속 튕기고...
# 2  앱 열기가 안 되네 여.. 삭제 후 재 설치..권한도 설정 들어가서 직접 했는데도 ...
# 3  카카오로 시작하기가 안 됩니다. 크롬에서 카카오로 가입 후 건 뱡 신청 했는데 어플...
# 4  앱 접속할 때마다 네트워크가 없다고 떠요. 어떻게 사용하라는 건가요? 그리고 간병 ...
#
#                                     tokenized_review  \
# 0  네트워크 오류 라고 나오다 와이파이 끄다 하다 로그인 안 되다 일시 적 인 오류 라...
# 1  카카오 로 시작 하다 가입 햇 늘다 로그인 후 카카오 로 로그인 이 안 되다 계속 ...
# 2  앱 열기 가 안 되다 여 .. 삭제 후 재 설치 .. 권한 도 설정 들어가다 직접 ...
# 3  카카오 로 시작 하다 안 되다 . 크롬 에서 카카오 로 가입 후 건 뱡 신청 하다 ...
# 4  앱 접속 하다 때 마다 네트워크 가 없다 뜨다 . 어떻다 사용 하 라는 건가 요 ?...
#
#                                      replaced_review  \
# 0  네트워크 오류 라고 나오다 와이파이 끄다 하다 로그인 안 되다 일시 적 인 오류 라...
# 1  카카오톡 로 시작 하다 회원가입 햇 늘다 로그인 후 카카오톡 로 로그인 이 안 되다...
# 2  애플리케이션 열기 가 안 되다 여 .. 삭제 후 재 설치 .. 권한 도 설정 들어가...
# 3  카카오톡 로 시작 하다 안 되다 . 크롬 에서 카카오톡 로 회원가입 후 건 뱡 신청...
# 4  애플리케이션 접속 하다 때 마다 네트워크 가 없다 뜨다 . 어떻다 사용 하 라는 건...
#
#                                      stopword_review one_word_removed
# 0  네트워크 오류 와이파이 로그인 안 일시 적 인 오류 뜨다 간병인 결정 결제 주말 이...
# 1  카카오 톡 시작 회원 가입 햇 늘다 로그인 후 카카오 톡 로그인 안 튕기 고 삭제 ...
# 2  애플리케이션 열기 안 삭제 후 재 설치 권한 도 설정 들어가다 직접 애플리케이션 안 리다
# 3  카카오 톡 시작 안 크롬 카카오 톡 회원 가입 후 건 뱡 신청 어플 카카오 톡 시작...
# 4  애플리케이션 접속 네트워크 뜨다 사용 건가 간병 금액 상한선 건 하루 당 30만원 ...

# %%
stop_words = " "
stop_words = set(stop_words.split(' '))
word_tokens = okt.morphs(text)

# %%
with open('drive/MyDrive/Colab Notebooks/stopwords.txt', 'r') as f:
  list_file = f.readlines()
stopwords = list_file[0].split(",")
remove_stopwords = [x for x in remove_one_word if x not in stopwords]
len(remove_stopwords)

# %%
Counter(remove_stopwords).most_common()
