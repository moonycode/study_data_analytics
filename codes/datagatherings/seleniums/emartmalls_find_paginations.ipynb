# %%
from selenium import webdriver

# %%
# open chrome browser
browser = webdriver.Chrome(executable_path='../../../../chromedriver.exe')

# %%
# url in address window
browser.get('https://emart.ssg.com/disp/category.ssg?dispCtgId=6000214033')

# %%
element_path = '#swiper-wrapper-c4ace0f8b9e18cd7 > li.mnemitem_grid_item.swiper-slide.swiper-slide-active > div > a > div.mnemitem_tit > span.mnemitem_goods_tit'
element = browser.find_element_by_css_selector(element_path)   # 단수 찾기
type(element)  # <span class="mnemitem_goods_tit">몰리스 쉬야응가 1회용 패드 L 50매</span>
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
element.text
# Out:
# '몰리스 쉬야응가 1회용 패드 L 50매'

# %%
element.get_attribute('class')
# Out:
# 'mnemitem_goods_tit'

# %% [markdown]
# ### 여러개 element 가져오기

# %%
element_path = '.mnemitem_goods_tit'
elements = browser.find_elements_by_css_selector(element_path)
type(elements), type(elements[0])

# %%
for webelement in elements : 
    try :
        print(webelement.text)
    except :
        pass

# %% [markdown]
# ### paginations
# - page 2 tag : #area_itemlist > div.paginate > div > a:nth-child(2)
# - page 2 tag : #area_itemlist > div.paginate > div > a:nth-child(7)

# %%
element_path = '#area_itemlist > div.paginate > div > a:nth-child(1)'
pagination = browser.find_element_by_css_selector(element_path)
pagination.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[5], line 2
#       1 element_path = '#area_itemlist > div.paginate > div > a:nth-child(1)'
# ----> 2 pagination = browser.find_element_by_css_selector(element_path)
#       3 pagination.click()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:598, in WebDriver.find_element_by_css_selector(self, css_selector)
#     582 def find_element_by_css_selector(self, css_selector):
#     583     """
#     584     Finds an element by css selector.
#     585
#    (...)
#     596         element = driver.find_element_by_css_selector('#foo')
#     597     """
# --> 598     return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
#     978     'value': value})['value']
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#area_itemlist > div.paginate > div > a:nth-child(1)"}
#   (Session info: chrome=116.0.5845.141)

# %%
browser.implicitly_wait(10)

# %%
import time

for page_number in range(1, 11):  # 첫 페이지는 tag 달라짐
    element_path = 'div.paginate > div > a:nth-of-type({})'.format(page_number)
    try :
        pagination = browser.find_element_by_css_selector(element_path)
        pagination.click()    
        print('성공 : {}'.format(element_path))
        
        time.sleep(3)
        element_title_path = '.mnemitem_goods_tit'
        webelements = browser.find_elements_by_css_selector(element_title_path)
        
        for webelement in webelements:
            try :
                print(webelement.text)
            except :
                pass
        
    except :
        print('실패 : {}'.format(element_path))
        pass
# Out:
# 성공 : div.paginate > div > a:nth-of-type(1)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [시저 Cesar] 비프 앤 치즈 사료 (100g*3)
# 뉴트리나 건강백서 건강한 관절 2kg
# 윌로펫 뉴트리탑 면역(전연령) 1.2kg
# 몰리스픽 전연령 반려견 사료 15kg
# 템테이션 믹스업 닭고기 연어 체다치즈맛 75g
# 챠오 츄르 가다랑어포 4개입
# 캣차우 컴플리트 전연령용 6kg
# [비타크래프트] 비타 캣스틱 연어 18G
# 헌터본 사슴 16P 240g
# 쉬바참치와연어파우치6팩 420g
# [시저 Cesar] 쇠고기와 참치 사료 100g*3팩
# 칠면조힘줄 하드링(s)
# 몰리스 냄새잡는 패드 L 35매
# 쉬바 참치와 연어 70g
# 치카치카 우유 치실껌 SS 48g
# 쉬바 참치 슬라이스와 그레이비 소스 85g
# 쉬바 참치와 닭고기 70g
# 몰리스 쉬야응가 1회용 패드 L 50매
# [몰리스]프로발란스 피부관리와 모질강화 전연령 6kg
# 캣츠스프링 벤토나이트모래 무향 10L
# [더독] 반려견용 치약 70g
# [쉬바] 참치 살코기와 통새우와 그레이비 소스 85g
# 포켄스 덴티페어리 SS 65g
# 덴티츄 구강&눈 사슴고기 21개입
# 자연소재 어포&오리고기180G
# 쉬바 참치살코기와 게살그레이비소스85g
# 몰리스 짜먹는 대구살 56g
# 시저 14세 이상 쇠고기와쌀과야채100Gx3
# Think your dog teeth 소가죽우유껌 44P(25
# ThinkYourDogTeeth소고기딩고우유껌스틱20P
# 몰리스 쉬야응가 튀지않는 패드(L)
# 치카치카 치실껌SS 20P(120g)
# Think your dog teeth 소가죽우유껌 18P(25
# 포켄스 말티즈 전용 샴푸&린스
# 몰리스 짜먹는 게맛살 56g
# 이나바 금빛육수 닭가슴살&가츠오부시 70g*1개
# 슈퍼츄 터키츄 본S 1개입
# 뉴트리나 건강백서 건강한 피부 2kg
# 이나바 금빛육수 컵 닭가슴살&가리비 70g*1개
# [위스카스 whiskas]주니어 오션피쉬 1.1kg
# 에티펫 얼룩냄새깨끗 청소티슈
# 캣츠스프링 벤토나이트모래 유향 10L
# 몰리스 덴탈껌 비타민 300g
# 몰리스 크런치홀릭 참치 60g
# 마이독 스테이크하우스 소고기 큐브 200g
# 완피 크리미트릿 치킨 70g (14g*5P)
# 포비스 귀세정제 100ml
# 헬씨미요 고양이간식 소고기(100g)
# 보양대첩 쿨링-오리와 황태1.8kg
# 몰리스 덴탈껌 우유칼슘 300g
# 쉬바 참치 흰살과 젤리 소스 85g
# 포켄스 과일먹은 치즈덴탈껌 딸기 100g
# New캐츠랑 전연령7kg
# Think your Dog Teeth 연어우유껌 15P
# 시저 11세이상 닭고기 100Gx3
# 국민가격 NTC 돼지귀 슬라이스 300g
# 몰리스 짜먹는 연어 56g
# 팬시피스트 인스퍼레이션 치킨&시금치 70g
# 이나바 금빛육수 컵 닭가슴살&치어 70g*1개
# 몰리스픽 비프고구마져키 1KG
# 시저 11세 이상 쇠고기 100gx3
# 포켄스 푸들 전용 샴푸&린스
# [시저 Cesar] 닭고기 사료 100g*3팩
# [비타크래프트] 비타 캣스틱 코어피쉬 18g
# 완피 크리미트릿 참치&연어 70g (14g*5P)
# 국민가격 NTC 돼지족발 400g
# [시저 Cesar] 불고기 사료 100g*3팩
# 포켄스 탈취제 은은한 베이비 파우더향
# 밥이보약 Dog 알맞은체중 2kg
# [비타크래프트] 캣스틱 치킨 캣그라스18g
# Think your dog teeth 소가죽우유껌 6P(210
# 위스카스 테이스티믹스 닭고기,참치와 당근 in 그레이비 70g*6개
# 위스카스 참치 (80g * 6개)
# 츄르비 닭가슴살&구운닭가슴살 4개입
# 밥이보약 DOG 튼튼한 관절 2kg
# 지위픽 독 소고기 1kg
# [비타크래프트] 캣얌 치킨캣그라스40g
# [시저 Cesar] 양고기 사료 100g*3팩
# 몰리스픽 치킨저키 300g
# 30days 연어츄르 30개입
# 성공 : div.paginate > div > a:nth-of-type(2)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 반려견패드(중)40*50cm*100매
# 반려견패드(대)60*70cm*45매
# 순살듬뿍 치킨말이스틱 30P (300g)
# 순살듬뿍 오리말이스틱 30P (300g)
# 건강한간식 순살듬뿍 고구마 오리말이 300g
# 건강한간식 순살듬뿍 고구마 치킨말이 300g
# 몰리스픽 반려견 패드 L 45매
# 건강한간식 순살듬뿍 안심오리 300g
# 반려견 사료 10kg
# 몰리스 화이트 스틱껌 소프트치킨 400g
# 템테이션 맛있는 닭고기맛 75g
# 몰리스픽 반려견 패드 M 100매
# 국민가격 DTC 치킨고구마 져키 1kg
# 몰리스 미끄러지지 않는 패드 M 80매
# 몰리스 쉬야응가 1회용 패드 M 100매
# 템테이션 고소한 참치맛 75g
# 건강한간식 순살듬뿍 안심치킨 300g
# 치킨 슬라이스 1kg
# 몰리스 미니 닭가슴살과 연어
# 포켄스 덴탈스틱 후레시 칼슘 S 작은별 220g
# 템테이션 믹스업 참치 연어 새우맛 75g
# 츄잉스틱 플레인요거트 250g
# 자연소재 양고기육포&쌀 460g
# 밥이보약 Dog 튼튼한 관절 8kg (네오2 유통기한 23.10.17)
# 템테이션 풍부한 해산물 맛75g
# 몰리스 3~4회용 패드 L 35매
# 포켄스 덴탈스틱 후레시 블루베리 S 작은별 220g
# [몰리스]프로발란스 어덜트 8kg
# (이마트가 직접 수입한) 딱 한번 반려견 패드 M 200매
# 자연소재 소고기육포스틱 180g
# 국민 두부 고양이 모래(오리지널)
# 포켄스 덴티페어리 M 75g
# 포켄스 덴티페어리 SS 150g
# 맥시 비프져키 800g
# 몰리스미니참치와도미
# [포켄스] 덴티 페어리(소)
# 원더푸드 반려견 고구마말랭이 간식 1kg
# 챠오 츄루 참치 4개입
# 챠오 츄르 참치/해물믹스맛 20개입
# 순살간식 오리고기 순살 300g
# 해피밀 황태와 소고기 1.2kg
# 몰리스 미끄러지지 않는 패드 L 35매
# 포켄스 덴탈스틱 후레시 오메가3 S 작은별 220g
# 몰리스픽 전연령 반려묘사료 15KG
# 몰리스 닭가슴살과흰살생선
# 슈퍼츄 터키츄 본S 10개입
# Think your Dog Teeth 소고기우유껌 15P
# [시저] 연어와 감자 (100g*3개)
# 몰리스 3~4회용 패드 M 80매
# 반려묘사료 10kg
# 몰리스 크런치홀릭 닭고기 60g
# 템테이션 연어맛 75g
# [쉬바] 참치 흰 살과 도미와 그레이비 소스 85g
# 칠면조힘줄 스트립 85g
# 챠오 츄르 닭가슴살 4개입
# 몰리스픽 전연령 반려묘사료 5KG
# Natural 밀크스틱27P(80g)
# 몰리스미니참치와게맛살
# [시저 Cesar] 비프 사료 100g*3
# 후코홀릭 명태베리
# [쉬바] 촉촉한 닭가슴살과 그레이비 소스 85g
# 위스카스 캣 주니어 포켓 오션피쉬 1.1kg (2~12개월)
# 해피밀 황태와 오리 1.2kg
# 몰리스 크런치홀릭 연어 60g
# 국민 두부 고양이 모래(녹차)
# 헌터본 연어 16P 240g
# 챠오 츄르 가다랑어 4개입
# 해피밀 황태와 연어 1.2kg
# 몰리스 쉬야응가 1회용 패드 XL 40매
# 템테이션 부드러운 우유맛 75g
# [시저] 흰살생선과 야채 (100g*3개)
# 슈퍼츄 터키츄 링S 1개입
# 내츄럴랩 건강한치즈 애견간식 요거트 스틱 100g
# 보양대첩 쿨링 30g캔 *8입
# 자연소재 오리고기 육포스틱 460g
# 츄르비 닭가슴살&구운가다랑어 4개입
# 몰리스 냄새잡는 패드 M 80매
# 츄잉스틱 딸기요거트 250g
# 가 직접 수입한 치킨 화이트본 S 13개입
# 몰리스 치즈 화이트스틱껌 치킨 270g
# 성공 : div.paginate > div > a:nth-of-type(3)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 컬러푸드 흑미고구마 스낵 460g
# 고양이습식캔(닭안심과연어)160g
# [시저]쇠고기(100g*12팩)
# 몰리스 퓨레스틱 연어 50g
# [몰리스]프로발란스 어덜트 3kg
# 몰리스픽 치킨 고구마말이 500g
# 완피 크리미트릿 참치&새우 70g (14g*5P)
# 프리스키 파티믹스 믹스그릴 60g
# 쉬바참치와닭고기파우치6팩 420g
# 위스카스 파우치 고등어와 연어 80g
# 팬시피스트 키튼터키멀티팩(85g*3)
# 닥터할리펫밀크캣
# 포켄스 포메라니안 전용 샴푸&린스 550ml
# 팬시피스트 그레이비 흰살생선멀티(85g*3)
# 닥터할리펫밀크시니어
# 완피 크리미트릿 참치&대구 70g (14g*5P)
# 팬시피스트 연어 멀티팩(85g*3)
# 웨루바 아시안퓨전 참치&치어 90g
# 퓨리나 베긴 스트립 베이컨 소고기맛 170g
# 헬씨미요 고양이간식 가다랑어 100g
# [비타크래프트] 크리스피크런치 연어60g
# [시저 Cesar] 허브딜과 치즈 쇠고기 사료
# 트윈펫보올 2구
# 프리스키 파티믹스 오리지날 60g
# [비타크래프트] 비타 크리스피크런치 몰트(헤어볼) 60g
# 펫둥이 올바디 펫티슈 70매
# 원데이케어 건강한 눈 12개입
# 웨루바 파우치 러브미텐더 닭&참치&오리 85g
# 일킬로그램 가득담은 치킨우유껌 1kg
# 지위픽 독 치킨 1kg
# 닥터할리 펫밀크 키튼 180mL
# 몰리스 소프트 오리 져키 250g
# [비타크래프트] 비타 크리스피크런치 폴트리(치킨) 60g
# 후코홀릭 후코이단
# 챠오 츄르 조갯살 4개입
# 바닐라향 알파카 그레이
# 펫둥이 올바디 펫티슈 30매
# 후코홀릭 대구살 80g
# 위스카스 포켓 구운 고등어 1.2kg
# 조앤강 오키로스틱 화이트(칠면조)
# [동원 x 몰리스] 러브투게더 고양이 습식캔 160g x 24입
# 원데이케어 건강한 유산균 12개입
# 보양대첩 워밍 30g캔 *8입
# 뉴질랜드에서 온 ZEAL 송아지꼬리 125g
# 퓨리나 베긴 스트립 베이컨 치즈맛 170g
# [위스카스whiskas] 고등어와 연어 80g
# 몰리스 내츄럴껌 하드치킨 350g
# 닥터소프트 명작 하이포알러지 연어 시니어 1.2kg
# 허즈 강아지 알러지 눈물사료 칠면조 908g
# 몰리스 퓨레스틱 닭고기 50g
# 위스카스파우치 주니어 고등어 (80g*6개)
# 몰리스픽 츄잉스틱 딸기요거트 250g
# [시저 Cesar] 불고기 사료 100g*3팩
# 덴탈라이프 미니 독 193g
# [웅자] 오리하드슬라이스(300g)
# 펫스테이지 우드스틱S 217
# 몰리스픽 오리목뼈 400g
# 아침애 플러스 한우 800g
# 팬시피스트 인스퍼레이션 연어&애호박 70g
# 칠면조힘줄 하드본(m)
# 웨루바 citk 보니타 고등어&참치&새우 90g
# [기획팩] 빈즈라이크 오리날개 1kg
# 동결건조 트릿 75g (북어)
# 셰프요리 연어 야채 400g
# 몰리스 소프트 치킨 져키 400g
# [몰리스]프로발란스 캣 어덜트 1.5kg
# 에티펫 시작부터칫솔
# 쉬바 참치와 게살 70g
# 개찹_애견장난감
# 쉬바 참치와 도미 70g
# 밥이보약 CAT 걱정없는 헤어볼 2kg
# 완피 크리미퓨레 혼합 25P
# 러브투게더 160g*24입
# 몰리스픽 치킨고구마져키 1KG
# 몰리스 치킨랩츄 300g
# 보양대첩 하모니-연어와 브로콜리50g
# [위스카스whiskas] 주니어 참치 80g
# 위스카스파우치 구운 고등어 (80g)
# 몰리스 체다치즈볼 (210g)
# 불리스틱 소형
# 성공 : div.paginate > div > a:nth-of-type(4)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 아투 독 오리 1.5kg
# 몰리스 짜먹는 고등어 56g
# [시저 Cesar] 쇠고기와 참치 사료 100g*3팩
# 반려견 골든 황태(스틱)
# 가 직접 수입한 치킨 화이트본 M 3개입
# [시저 Cesar] 비프 앤 치킨 사료 100*3g
# 에티펫 눈물자국 깨끗시트 (30매)
# 몰리스픽 오리저키 300g
# 닥터할리펫밀크바닐라
# 몰리스 쉬야응가 튀지않는 패드 M 45매
# 몰리스 크런치홀릭 양고기 60g
# 더독 수제 삼계탕
# 부들부들 덴탈 케어 치약
# 뉴트리나 건강백서 푸들 2kg
# 아스크 게살 슬라이스 50g
# 건강백서 비숑 2kg
# 30days 닭가슴살 30개입
# 덴티츄 구강&면역 양고기 21개입
# 몰리스 덴탈껌 우유칼슘 300g
# 미유믹스 리얼 치킨과 비프 78g
# [기획팩] 빈즈라이크 오리목뼈 1kg
# 원데이케어 건강한 관절 12개입
# [위스카스whiskas] 키튼참치 80g
# 챠오 쁘띠 참치 5개입
# 셰프요리 칠면조 순살 400g
# 뉴트리나 건강백서 말티즈 2kg
# ThinkYourDogTeeth연어딩고우유껌스틱20P
# 뉴트리나 건강백서 건강까지 챙기는 쌀로 만든 껌 120g
# 건강백서 베지버거 100g
# 헬씨미요 고양이간식 참치 100g
# Think your dog teeth 소가죽우유껌 3P(210
# 빈즈라이크 국내산 오리날개 500g
# 카샤카샤 붕붕 와이어 낚시대
# 몰리스 하드 오리 져키 250g
# 덴탈카리에스 280g
# [비타크래프트] 비타 캣얌 치즈 40G
# 밥이보약 CAT 빛나는 피모 2kg
# 밥이보약 CAT NO스트레스 2kg
# 프리스키 파티믹스 피크닉 60g
# [몰리스]프로발란스 관절강화 및 연골보호 전연령 2.6kg
# 에티펫 부드럽게칫솔(누구나)
# 퓨리나 알포 성견용 소고기맛 3kg
# [국민가격]골든황태(채)
# 밥이보약 CAT 알맞은 체중 2kg
# 몰리스 쉬야응가 1회용 패드 S 120매
# 챠오 츄르 참치&연어 4개입
# 가 직접 수입한 치킨 화이트본 S 5개입
# [비타크래프트] 비타 캣얌 연어 40G
# 파티믹스 치킨 60g
# [쓱배송] 60days 고양이간식 츄르(12g*60ea)
# 미유믹스 버라이어티팩 치킨,참치,새우 936g
# [시저 Cesar] 비프 앤 치킨 사료 100*3g
# 위스카스파우치 고등어 (80g*6개)
# 더독 4220 치약
# 지위픽 독 사슴고기 1kg
# 팬시피스트 연어 멀티팩(85g*3)
# 몰리스픽 오리 고구마말이 500g
# 불리스틱 중소형 6p
# 팬시피스트 치킨 튜나 플레이크 멀티(85g*3)
# 뉴트리나 건강백서 건강한 체중 2kg
# 서울우유 아이펫밀크 70ml x 3팩
# 시저 간식 사과, 양배추와 고구마 큐브 100g
# 몰리스 화이트스틱껌 소프트 오리 400g
# 서울우유 아이펫밀크 180ml x 3팩
# [시저 Cesar] 닭고기 사료 100g*3팩
# 손가락 칫솔 (1회용)
# 몰리스픽 짜먹는 연어
# 덴티츄 구강&관절 캥거루 21개입
# 포켄스 덴티페어리 S 150g
# 퓨리나 베긴 스트립 베이컨 오리지날 170g
# 발톱가는 고양이 쇼파형 스크래쳐
# [비타크래프트] 크리스피크런치 덴탈60g
# 몰리스픽 반려견 패드 XL 35매
# 헬씨미요 고양이간식 멸치(60g)
# 몰리스픽 전연령 반려견 사료 2kg
# 위스카스 시니어 참치 80g
# 원데이케어 건강한 피부 12개입
# [시저]쇠고기와 닭고기(100g*12팩)
# 후코홀릭 황태와야채 120g
# 포켄스 베이비파우더 샴푸 550ml
# 성공 : div.paginate > div > a:nth-of-type(5)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 후코홀릭 국내산 강아지 수제간식 황태 한우김밥 80g
# [위스카스 whiskas] 파우치 주니어 고등어80g
# 뉴트리나 건강백서 야들야들 쫀득한 닭고기 120g
# 허즈 강아지 알러지 눈물사료 닭가슴살 908g
# 포켄스 오트밀 샴푸 550ml
# 쉬바 닭고기와 참치 in 그레이비소스 70g
# 퓨리나 원 캣 성묘용 실내고양이 1.4kg
# 동결건조 트릿 100g (치킨)
# 내츄럴랩 건강한치즈 애견간식 블루베리 스틱 100g
# 템테이션 헤어볼 컨트롤 60g
# 일킬로그램 가득담은 오리우유껌 1kg
# 에티펫 치아깨끗시트 30매
# [시저 Cesar] 양고기 사료 100g*3팩
# 강아지 바비큐 장난감
# ANF 치킨순살캔 95G
# 터키츄 칠면조와 소고기 힘줄 링S_30P
# 뉴 바스락삑삑 바나나
# 캣차우 3kg
# 서울우유 아이펫밀크 저지방 180ml
# 뉴트리플랜참치&닭가슴살160g
# 바잇미 웁스백 배변봉투
# 위스카스 테이스티믹스 씨푸드칵테일과미역in그레이비70g
# 뉴트리나 건강백서 건강한 피부 6kg
# 하림펫푸드 더리얼 크런치 소고기 어덜트 1kg
# [Cesar 시저] 연어맛이 곁들여진 프리미엄 쇠고기 1kg
# 지위픽 독 양고기 1kg
# 위스카스 테이스티믹스 닭고기,연어와미역in그레이비 70g
# [더독] 반려견용 치약 70g
# 퓨리나 알포 성견용 소고기맛 3kg
# 카네토라 파우치 가다랑어
# 하림펫푸드 더리얼 오븐베이크드 닭고기 어덜트 1kg
# [웅자] 하드슬라이스치킨(300g)
# [이마트가 직접 수입한] 컬러볼(중)
# 이즈칸캣 영양듬뿍 기력보충 닭고기참치스튜 80g
# 풉백 16롤 x 15매 (240장)
# 뉴트리나 건강백서 건강한 스트레스 2kg
# 뉴트리플랜참치&멸치160g
# 뉴트리플랜참치와 치즈 160G
# 헬씨미요 고양이간식참치슬라이스50g
# 캣파우 레인보우 마우스 롱낚시대
# 슈퍼츄 터키츄 링S 10개입
# 건강백서 얇게 썰어 먹기 좋은 닭고기 120g
# 캣츠미어 참치&도미토핑
# 후코홀릭 명태녹차
# 빈즈라이크 국내산 오리목뼈 500g
# 펫스테이지 크런치코어본M 265
# 위스카스 캣 포켓 헤어볼 닭고기와 참치 1.1kg
# 몰리스 프로발란스 닭고기 300g(100g*3)
# [동원 x 몰리스] 러브투게더 고양이 습식캔 160g
# 캔 쇠고기맛 700g
# 포켄스 덴탈스틱 후레시 오메가3 M 큰별 220g
# 쉬바 파우치 참치 70g
# 위스카스 테이스티믹스 닭고기,참치와당근in그레이비70g
# 펫트너쉽 360도 애견칫솔
# 지위픽 독 트라이프&양 1kg
# 치카치카 우유 치실껌 S 48g
# [이마트가 직접 수입한] 휴대용물병 300ml
# 에티펫 귀깨끗시트 30매
# 자연소재 비프스틱 460g
# 순살간식 닭고기 순살 300g
# 몰리스 치킨&대구 큐브
# 시저14세 이상 닭고기와쌀과야채100Gx3
# 독 러브미 비프&치즈 100g
# ANF 고양이참치무스캔 95G
# 포켄스 말티즈 전용 샴푸&린스 550ml
# ANF고양이참치순살캔95G
# 풋 버블 클렌저
# [기획팩] 마이독 스테이크하우스 연어 큐브 200g x 2개
# 웰니스코어 시그니쳐셀렉트플레이크 참치와연어79g
# [몰리스]프로발란스 캣 전연령용 6kg
# ANF 치킨비프캔 95G
# 카네토라 파우치 해물맛
# 뉴트리나 건강백서 얇게 썰어 먹기 좋은 오리고기 120g
# 프리스키 파티믹스 비치사이드 60g
# 밥이보약 DOG 활기찬 노후 2kg
# ANF 네이처스키친 관절건강 레시피_2kg
# 포켄스 덴티페어리 디스펜서 S 80개입
# ANF 고양이참치게맛살캔 95G
# 시리우스 윌 반려견 간식 언더텐 곤약껌 20G
# 위스카스 캣 포켓 오션피쉬 1.2kg
# 성공 : div.paginate > div > a:nth-of-type(6)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 포켄스 덴탈스틱 후레시 칼슘 M 큰별 220g
# 기린칫솔
# [몰리스]프로발란스 캣 키튼 1.5kg
# 뉴트리나 건강백서 헬씨버거 100g
# 아투 독 치킨 1.5kg
# 위스카스 구운 고등어 (80g*6개)
# 밥이보약 관절튼튼 건강볼 38g
# 보양대첩 워밍-소고기와 초록입홍합50g
# 터키츄 칠면조와 소고기 힘줄 본S_30P
# 팬시피스트 인스퍼레이션 참치&통곡물 70g
# 팬시피스트 인스퍼레이션 비프&토마토 70g
# 더독 치킨 치즈 슬라이스 100g
# 뉴 바스락삑삑 당근
# 챠오 츄르 닭가슴살/해물믹스맛 20개입
# 펫츠루트 셰프요리 닭가슴살 야채 400g
# 펫츠루트 셰프요리 닭가슴살 치즈 400g
# New캐츠랑 전연령2kg
# 월간통살 황태 600g (20g*30p)
# 밥이보약 DOG 튼튼한 관절 2kg
# 프로베스트캣푸드 참치와치킨_80g
# ANF 고양이참치새우캔 95G
# 몰리스 먼치껌 20P 150g
# 뉴트리나 건강백서 노릇노릇 고구마와 닭고기 120g
# 몰리스 프로발란스 장건강 300g(100g*3)
# 헌터본 양 16P 240g
# 몰리스픽 츄잉스틱 플레인요거트 250g
# 미유믹스 버라이어티팩 칠면조,치킨,비프 936g
# [시저 Cesar] 허브 타임과 호박 닭고기 사료
# 몰리스 덴탈껌 우유칼슘 300g
# 시저 간식 딸기, 바나나와 우유 슬라이스 100g
# 동원 뉴트리플랜 건강프로젝트 면역&유리너리 160g
# 칼리 라텍스 하마
# [웅자] 미니칼슘닭갈비(100g)
# 뉴트리나 건강백서 건강한 6세+ 2kg
# 하림펫푸드 더리얼 오븐베이크드 소고기 어덜트 1kg
# 칠면조힘줄 하드링(m)
# 밥이보약 면역쑥쑥 건강볼 38g
# 독 러브미 치킨 100g
# 30days 참치츄르 30개입
# 고스비 cat 참치&연어
# 몰리스 비프 져키믹스
# [기획팩] 마이독 스테이크하우스 소고기 큐브 200g x 2개
# 프리스키 파티믹스 캘리포니아 60g
# 고스비 cat 참치연어&파파야
# [비타크래프트] 퓨어스틱 코어피쉬 20g
# 포켄스 댕댕아 발씻자 발세정제 300ml
# 몰리스 치즈 소프트 치킨 300g
# 포비스 덴탈크린치약 100ml
# [웅자] 하드슬라이스치킨(300g)
# 밥이보약 Dog 빛나는 피모 8kg (네오2 유통기한 23.10.16)
# ANF 고양이참치치킨무스캔 95G
# ANF 고양이참치연어캔 95G
# 쥬크루 리얼사운드 쥐
# 보양대첩 쿨링-오리와 단호박50g
# 장수풍뎅이발효톱밥3L
# 캐티맨 강아지풀 낚시대(50cm)
# 퓨리나 베긴 스트립 베이컨 피넛버터맛 170g
# 프로베스트캣푸드 참치와연어_80g
# 종합캣닢
# 에티펫 손발엉덩이깨끗티슈 40매
# 시리우스 윌 반려견 간식 비프 스테이크 스틱 100G
# 독 러브미 양고기 100g
# 시리우스 윌 반려견 간식 연어 스테이크 스틱 100G
# 뉴 바스락삑삑 프레첼
# 퓨리나 원 피부건강 2kg
# 위스카스파우치 참치 80g
# ANF 6FREE 소고기 8kg
# 지위픽 독 고등어&양 1kg
# ANF 6FREE 오리 8kg
# [위스카스 whiskas] 파우치 주니어 고등어80g
# 웨루바 citk 펑크인더트렁크 닭&참치&호박 90g
# 퓨리나 알포 성견용 소고기맛 10kg
# 더독 수제 삼계죽 150g
# 아이클리닝패드
# 밥이보약 DOG 건강한 장 2kg
# [기획팩] 마이독 스테이크하우스 오리 큐브 200g x 2개
# ANF 6FREE 연어 8kg
# 웨루바 파우치 맥잭앤샘 연어&고등어&참치 85g
# 쉬바 참치, 호박과 당근 in 그레이비소스 70g
# 풀무원아미오 건강담은 칠면조육포50g
# 성공 : div.paginate > div > a:nth-of-type(7)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 풀무원아미오 칼슘담은 닭가슴살50g
# 캣츠미어 참치와 흰살토핑 170g
# 펫모닝 스윙캣 벌
# 팬시피스트 통치킨 파이 캔(85g*3)
# 윌로펫 뉴트리탑 어덜트 1.2kg
# 덴탈라이프 트릿 치킨 캣 51g
# 이즈칸캣 영양듬뿍기력보충 닭고기야채죽80g
# 웨루바 citk 치킨 프리카세 닭 90g
# 테라펠리스 칠면조
# 쉬바 닭고기 무스 70g
# 하림펫푸드 더리얼 크런치 연어1kg
# [몰리스]프로발란스 피부관리와 모질강화 전연령 2.6kg
# ANF 6FREE 연어 8kg
# 우주선 푸드토이 중형 (디자인 랜덤)
# 자연소재 닭모래집 130g
# 펫스테이비 바비큐 우드스틱 P(30142)
# 펫모닝 닭가슴살
# 윌로펫 뉴트리탑 시니어 1.2kg
# C웰니스 헬시 인덜전스 머셀 참치85g
# ANF 6FREE 양고기 8kg
# 이즈칸캣 영양듬뿍기력보충 가쓰오닭고기스프 80g
# 하림펫푸드 더리얼 오븐베이크드 연어 1kg
# 포켄스 뉴트리션트릿 눈&눈물 240g
# [포비스] 항균 탈취제 (라임향) 1000ml
# 자연소재 연어스틱 460g
# 더리얼 캣 그레인프리 크런치 닭고기 1kg
# [몰리스]프로발란스 캣 헤어볼 1.5kg
# 원더푸드 낙지쇠고기죽 120g
# 독 6FREE 플러스 레드 소고기&연어 5.6kg
# 몰리스 치즈 소프트 오리 300g
# 동원 뉴트리플랜 건강프로젝트 체중조절&관절 160g
# 챠오 츄르 하이볼 참치 4개입
# 포켄스 바이비드 약용샴푸 300ml
# 보양대첩 워밍-닭고기와 고구마 50g
# 츄르소프트 미니트릿 치킨 버라이어티 27g x 7개입
# 퓨리나원캣 성묘용 순살연어 1.5kg
# [위스카스whiskas] 고등어와 연어 80g
# 건강한간식 오메가트릿 연어 400g
# [몰리스]프로발란스 캣 전연령용 2kg
# 시저홀썸볼 쇠고기,닭고기,당근,고구마85g
# 버츠비 이치 수딩 샴푸 4736ml
# 동원 뉴트리플랜 건강프로젝트 피부&모질 160g
# 쉬바 7세이상 참치와 게살과 그레이비소스 85g
# 캣츠미어 참치&치킨토핑
# 하림펫푸드 더리얼 크런치 닭고기 어덜트 1kg
# 너를위한디저트 고양이 캣닢비스켓 참치맛
# 몰리스 프로발란스 관절건강 300g(100g*3)
# 츄러스 스크래쳐
# 몰리스 마들렌 고구마 60g
# Natural 밀크스틱6P
# 건강백서 치킨 브레스트 100g
# 야들야들 소고기120g
# 바닐라향 브이 로프토이
# 몰리스 반려견용 쿠키 1kg
# Natural 밀크스틱4P(60g)
# 건강백서 시니어(10세+) 2kg
# 케어플 발톱깎이(아치형)
# 포비스 항균 탈취제 (라벤더향) 1000ml
# 동결건조간식(북어)90g
# 프리스키 파티믹스 치즈크레이지 60g
# 캣템 스피루리나 덴탈 치킨 60g
# 동원 뉴트리플랜 건강프로젝트 장&유리너리 160g
# 캣파우 나비롱 낚시대
# 찜쿡 닭가슴살 치즈츄러스400g
# 몰리스 내츄럴껌 1P 60g
# 시리우스 윌 반려견 간식 언더텐 콜라겐껌 20G
# 몰리스 연어&대구 슬라이스 정보관리
# 윌로펫 헬시포뮬러 힙앤조인트 1.2kg
# 아메리칸솔루션6.35 언씬티드
# 몰리스 오리&대구 슬라이스
# 조앤강 오키로스틱 옐로우(닭가슴살)
# 너를위한디저트 고양이 캣닢비스켓 치킨맛
# 츄르비 참치&구운닭가슴살 4개입
# 캣파우 루어 롱낚시대
# [MOLLYS 몰리스]애견 패드판(색상 랜덤발송) [(가로)49(세로)40.5*(높이)4cm]
# 몰리스 화이트 스틱껌 60g
# 동결건조 열빙어 80g
# 동결건조 트릿 100g (치킨)
# 치약 칫솔 셋트
# 보양대첩워밍 소고기와 연어 80g
# 성공 : div.paginate > div > a:nth-of-type(8)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 더독 수제 오리탕
# 건강한간식 연골 오리말이 220g
# 페슬러 묘설렘 닭고기맛
# 셰프요리 유산균 연어와치즈
# 펫모닝 바닐라향 물고기
# 뉴 바스락삑삑 티라노
# 너를위한디저트 고양이 캣닢비스켓 연어맛
# SZ) 플라잉피쉬 낚시대
# 끈질긴 로프토이 고리
# 테라카니스 카니레오 1kg
# 뉴트리나 건강백서 포메라니언 2kg
# 아메리칸솔루션
# 카샤카샤 붕붕 슈퍼롱 낚시대
# 웰니스코어 시그니쳐셀렉트슈레드 닭고기와닭간79g
# 똑똑한입 포천 이동갈비 250g
# 포켄스 알로에 향수&컨디셔너 베이비파우더향 300ml
# ANF 네이처스키친 장건강 레시피_2kg
# 앤티크원형방석 M
# 앱솔루트 바이트 자연건조 고구마 1kg
# 몰리스 치킨&대구 슬라이스 정보관리
# 오리목뼈400g
# 캣스토랑 크랩미트 80g
# 에임 소프트 생닭고기 홀리스틱1.2kg
# 캣츠미어 참치오리지날
# [MOLLYS 몰리스]애견 패드판 (색상 랜덤배송)[(가로)49(세로)40.5*(높이)4cm]
# 형광공
# 부들부들 손가락 칫솔
# [웅자] 하드슬라이스치킨(100g)
# 포와이즈 리필용 배변봉투
# 슈퍼츄 터키츄 본M 1개입
# 프로베스트캣푸드 참치와게맛살_80g
# 더독 수제 북어국
# 더펫원츠 일체형 치약&칫솔 멍치카펜
# 츄르소프트 미니트릿 야채&치즈 버라이어티 27g x 7개입
# 완피 크리미퓨레 치킨 25P
# [비타크래프트] 비타 퓨어스틱 치킨 20g
# 우드스틱SS 216
# 더독 오리고구마말이 1kg
# 몰리스 숯 패드 M 80매
# 칼리 라텍스 오리
# 캣파우 레인보우 공작깃털 롱낚시대
# [몰리스] 템테이션/팬시피스트/쉬바 고양이 점포인기상품
# 오리날개400g
# 칠면조힘줄 하드본(L)
# 윌로펫 뉴트리탑 퍼피 3kg
# LL 누빔슬링백 IV
# 월간통살 닭가슴살 600g (20g*30p)
# 프레쉬 독 테트라 터키 스튜 354g
# 챠오스틱 참치 4개입
# 조앤강 조공 한방보양 삼계탕전
# 콕치즈 65g
# 브로스 참치, 새우, 흰살생선 40g
# 더독 수제 오리죽 150g
# 초코펫 에브리데이하우스 2.0 베이직
# 캣 6FREE 플러스 어덜트 5.6kg
# 그린트리 호호바오일 샴푸 500ml
# 캣파우 빅 3단 낚시대
# 몰리스 내츄럴껌 260g
# 정글몬스터 덴티소프트 칫솔
# 아침애사료 플러스 오리
# 그리니즈 미니트리트팩티니340G
# 셰프요리 유산균 칠면조와야채
# 포비스 단모 고양이 전용 샴푸&린스 300ml
# [비타크래프트] 캣얌 리버소세지40g
# 후코홀릭 인섹트 도그 동애등에 관절 1kg
# 건강백서 면역케어 2kg
# 트로피크린-오트밀샴푸 592ml
# 캣가다랑어(자연맛)
# 더리얼 퀴진 황태무국
# 페슬러 묘설렘 대구맛
# 베베페페 수컷용 기저귀 대형 10매
# 순살듬뿍 오리지널30 닭고기 30p
# 시리우스 펫퓸 반려견 베이비파우더 샴푸 500ML
# 챠오 쁘띠 닭가슴살 5개입
# 보양대첩캣 오리, 계란과 샐러리 80g
# KURU Natural 밀크본S 4P 130g
# 헬로마이펫 댕댕카솔 진정크림(연두) 50g
# 오븐애 한입 닭가슴살 치즈 80g
# 바잇미 테니스공 장난감 3개입
# 챠오 츄르 유산균 참치 4개입
# 실패 : div.paginate > div > a:nth-of-type(9)
# 실패 : div.paginate > div > a:nth-of-type(10)

# %%
# browser.quit()
