# %% [markdown]
# ### 자연어 처리 시작

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp311-cp311-win_amd64.whl (151 kB)
#                                               0.0/151.4 kB ? eta -:--:--
#      -----------------------------------    143.4/151.4 kB 4.3 MB/s eta 0:00:01
#      -------------------------------------- 151.4/151.4 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.1 in c:\users\01-03\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\01-03\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\01-03\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\01-03\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\01-03\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\01-03\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\01-03\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\01-03\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\01-03\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\01-03\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\01-03\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2

# %%
from wordcloud import WordCloud

# %%
# 한글 문장 리스트
sentences = [
    "오늘 날씨가 좋아서 나들이 가고 싶다.",
    "이 영화는 정말 재미있었어요.",
    "맛있는 음식을 먹으러 갈까요?",
    "운동을 하면 건강에 좋아지는 것 같아요.",
    "공부하기 싫어서 미루고 있어요.",
    "여행 계획을 세우고 있는데 어디로 갈까요?",
    "좋은 책을 읽으면 마음이 편안해져요.",
    "오늘은 친구들과 만나서 재미있게 놀았어요.",
    "새로운 언어를 배우는 것은 어려워도 흥미로워요.",
    "주말에 가족들과 함께 시간을 보내기로 했습니다."
]

# %% [markdown]
# ### 자연어 처리 위한 단어 생성

# %%
text = ' '.join(sentences)
text
# Out:
# '오늘 날씨가 좋아서 나들이 가고 싶다. 이 영화는 정말 재미있었어요. 맛있는 음식을 먹으러 갈까요? 운동을 하면 건강에 좋아지는 것 같아요. 공부하기 싫어서 미루고 있어요. 여행 계획을 세우고 있는데 어디로 갈까요? 좋은 책을 읽으면 마음이 편안해져요. 오늘은 친구들과 만나서 재미있게 놀았어요. 새로운 언어를 배우는 것은 어려워도 흥미로워요. 주말에 가족들과 함께 시간을 보내기로 했습니다.'

# %%
## 조사 빼기
# 는, 이, 은, 를, 한, 가, ...
import re
pattern = r'[는은이가을를만의과에]'
re.sub(pattern=pattern, '', text) # params : 변경대상, 대상 대체, 어떤것을

# %%
text_split = text.split()
text_split

# %%
# 한글 폰트 경로 설정 (Window 환경)
malgun_font = 'C:/Windows/Fonts/malgun.ttf'
wordCloud = WordCloud(font_path=malgun_font)

# %%
wordCloud.generate_from_text(text)

# %%
wordCloud.words_
# Out:
# {'갈까요': 1.0,
#  '오늘': 0.5,
#  '날씨가': 0.5,
#  '좋아서': 0.5,
#  '나들이': 0.5,
#  '가고': 0.5,
#  '싶다': 0.5,
#  '이': 0.5,
#  '영화는': 0.5,
#  '정말': 0.5,
#  '재미있었어요': 0.5,
#  '맛있는': 0.5,
#  '음식을': 0.5,
#  '먹으러': 0.5,
#  '운동을': 0.5,
#  '하면': 0.5,
#  '건강에': 0.5,
#  '좋아지는': 0.5,
#  '것': 0.5,
#  '같아요': 0.5,
#  '공부하기': 0.5,
#  '싫어서': 0.5,
#  '미루고': 0.5,
#  '있어요': 0.5,
#  '여행': 0.5,
#  '계획을': 0.5,
#  '세우고': 0.5,
#  '있는데': 0.5,
#  '어디로': 0.5,
#  '좋은': 0.5,
#  '책을': 0.5,
#  '읽으면': 0.5,
#  '마음이': 0.5,
#  '편안해져요': 0.5,
#  '오늘은': 0.5,
#  '친구들과': 0.5,
#  '만나서': 0.5,
#  '재미있게': 0.5,
#  '놀았어요': 0.5,
#  '새로운': 0.5,
#  '언어를': 0.5,
#  '배우는': 0.5,
#  '것은': 0.5,
#  '어려워도': 0.5,
#  '흥미로워요': 0.5,
#  '주말에': 0.5,
#  '가족들과': 0.5,
#  '함께': 0.5,
#  '시간을': 0.5,
#  '보내기로': 0.5,
#  '했습니다': 0.5}

# %%
from collections import Counter
Counter(text_split)
# Out:
# Counter({'오늘': 1,
#          '날씨가': 1,
#          '좋아서': 1,
#          '나들이': 1,
#          '가고': 1,
#          '싶다.': 1,
#          '이': 1,
#          '영화는': 1,
#          '정말': 1,
#          '재미있었어요.': 1,
#          '맛있는': 1,
#          '음식을': 1,
#          '먹으러': 1,
#          '갈까요?': 2,
#          '운동을': 1,
#          '하면': 1,
#          '건강에': 1,
#          '좋아지는': 1,
#          '것': 1,
#          '같아요.': 1,
#          '공부하기': 1,
#          '싫어서': 1,
#          '미루고': 1,
#          '있어요.': 1,
#          '여행': 1,
#          '계획을': 1,
#          '세우고': 1,
#          '있는데': 1,
#          '어디로': 1,
#          '좋은': 1,
#          '책을': 1,
#          '읽으면': 1,
#          '마음이': 1,
#          '편안해져요.': 1,
#          '오늘은': 1,
#          '친구들과': 1,
#          '만나서': 1,
#          '재미있게': 1,
#          '놀았어요.': 1,
#          '새로운': 1,
#          '언어를': 1,
#          '배우는': 1,
#          '것은': 1,
#          '어려워도': 1,
#          '흥미로워요.': 1,
#          '주말에': 1,
#          '가족들과': 1,
#          '함께': 1,
#          '시간을': 1,
#          '보내기로': 1,
#          '했습니다.': 1})

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off')
plt.show()
