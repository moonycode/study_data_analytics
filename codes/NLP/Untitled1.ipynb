# %% [markdown]
# ### 한글 형태소 분석기
# - refer : https://konlpy-ko.readthedocs.io/ko/v0.6.0/

# %%
# !pip install konlpy
# Out:
# ...
#                                               0.0/19.4 MB ? eta -:--:--
#                                               0.2/19.4 MB 5.3 MB/s eta 0:00:04
#                                               0.5/19.4 MB 5.6 MB/s eta 0:00:04
#      -                                        0.8/19.4 MB 6.1 MB/s eta 0:00:04
#      --                                       1.0/19.4 MB 5.9 MB/s eta 0:00:04
#      --                                       1.2/19.4 MB 5.6 MB/s eta 0:00:04
#      --                                       1.3/19.4 MB 5.3 MB/s eta 0:00:04
#      --                                       1.4/19.4 MB 4.6 MB/s eta 0:00:04
#      ---                                      1.5/19.4 MB 4.3 MB/s eta 0:00:05
#      ---                                      1.6/19.4 MB 4.0 MB/s eta 0:00:05
#      ---                                      1.8/19.4 MB 3.9 MB/s eta 0:00:05
#      ---                                      1.9/19.4 MB 3.9 MB/s eta 0:00:05
# ...

# %%
from konlpy.tag import Okt

# %%
okt = Okt()
